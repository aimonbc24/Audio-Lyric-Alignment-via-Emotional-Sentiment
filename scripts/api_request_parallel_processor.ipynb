# %%
"""
API REQUEST PARALLEL PROCESSOR

Using the OpenAI API to process lots of text quickly takes some care.
If you trickle in a million API requests one by one, they'll take days to complete.
If you flood a million API requests in parallel, they'll exceed the rate limits and fail with errors.
To maximize throughput, parallel requests need to be throttled to stay under rate limits.

This script parallelizes requests to the OpenAI API while throttling to stay under rate limits.

Features:
- Streams requests from file, to avoid running out of memory for giant jobs
- Makes requests concurrently, to maximize throughput
- Throttles request and token usage, to stay under rate limits
- Retries failed requests up to {max_attempts} times, to avoid missing data
- Logs errors, to diagnose problems with requests

Example command to call script:
```
python examples/api_request_parallel_processor.py \
  --requests_filepath examples/data/example_requests_to_parallel_process.jsonl \
  --save_filepath examples/data/example_requests_to_parallel_process_results.jsonl \
  --request_url https://api.openai.com/v1/embeddings \
  --max_requests_per_minute 1500 \
  --max_tokens_per_minute 6250000 \
  --token_encoding_name cl100k_base \
  --max_attempts 5 \
  --logging_level 20
```

Inputs:
- requests_filepath : str
    - path to the file containing the requests to be processed
    - file should be a jsonl file, where each line is a json object with API parameters and an optional metadata field
    - e.g., {"model": "text-embedding-3-small", "input": "embed me", "metadata": {"row_id": 1}}
    - as with all jsonl files, take care that newlines in the content are properly escaped (json.dumps does this automatically)
    - an example file is provided at examples/data/example_requests_to_parallel_process.jsonl
    - the code to generate the example file is appended to the bottom of this script
- save_filepath : str, optional
    - path to the file where the results will be saved
    - file will be a jsonl file, where each line is an array with the original request plus the API response
    - e.g., [{"model": "text-embedding-3-small", "input": "embed me"}, {...}]
    - if omitted, results will be saved to {requests_filename}_results.jsonl
- request_url : str, optional
    - URL of the API endpoint to call
    - if omitted, will default to "https://api.openai.com/v1/embeddings"
- api_key : str, optional
    - API key to use
    - if omitted, the script will attempt to read it from an environment variable {os.getenv("OPENAI_API_KEY")}
- max_requests_per_minute : float, optional
    - target number of requests to make per minute (will make less if limited by tokens)
    - leave headroom by setting this to 50% or 75% of your limit
    - if requests are limiting you, try batching multiple embeddings or completions into one request
    - if omitted, will default to 1,500
- max_tokens_per_minute : float, optional
    - target number of tokens to use per minute (will use less if limited by requests)
    - leave headroom by setting this to 50% or 75% of your limit
    - if omitted, will default to 125,000
- token_encoding_name : str, optional
    - name of the token encoding used, as defined in the `tiktoken` package
    - if omitted, will default to "cl100k_base" (used by `text-embedding-3-small`)
- max_attempts : int, optional
    - number of times to retry a failed request before giving up
    - if omitted, will default to 5
- logging_level : int, optional
    - level of logging to use; higher numbers will log fewer messages
    - 40 = ERROR; will log only when requests fail after all retries
    - 30 = WARNING; will log when requests his rate limits or other errors
    - 20 = INFO; will log when requests start and the status at finish
    - 10 = DEBUG; will log various things as the loop runs to see when they occur
    - if omitted, will default to 20 (INFO).

The script is structured as follows:
    - Imports
    - Define main()
        - Initialize things
        - In main loop:
            - Get next request if one is not already waiting for capacity
            - Update available token & request capacity
            - If enough capacity available, call API
            - The loop pauses if a rate limit error is hit
            - The loop breaks when no tasks remain
    - Define dataclasses
        - StatusTracker (stores script metadata counters; only one instance is created)
        - APIRequest (stores API inputs, outputs, metadata; one method to call API)
    - Define functions
        - api_endpoint_from_url (extracts API endpoint from request URL)
        - append_to_jsonl (writes to results file)
        - num_tokens_consumed_from_request (bigger function to infer token usage from request)
        - task_id_generator_function (yields 0, 1, 2, ...)
    - Run main()
"""

# imports
import aiohttp  # for making API calls concurrently
import argparse  # for running script from command line
import asyncio  # for running API calls concurrently
import json  # for saving results to a jsonl file
import logging  # for logging rate limit warnings and other messages
import os  # for reading API key
import re  # for matching endpoint from request URL
import tiktoken  # for counting tokens
import time  # for sleeping after rate limit is hit
import asyncio
from dataclasses import (
    dataclass,
    field,
)  # for storing API inputs, outputs, and metadata


async def process_api_requests_from_file(
    requests_filepath: str,
    save_filepath: str,
    request_url: str,
    api_key: str,
    max_requests_per_minute: float,
    max_tokens_per_minute: float,
    token_encoding_name: str,
    max_attempts: int,
    logging_level: int,
):
    """Processes API requests in parallel, throttling to stay under rate limits."""
    # constants
    seconds_to_pause_after_rate_limit_error = 15
    seconds_to_sleep_each_loop = (
        0.01  # 1 ms limits max throughput to 1,000 requests per second
    )

    # initialize logging
    logging.basicConfig(level=logging_level)
    logging.debug(f"Logging initialized at level {logging_level}")

    # infer API endpoint and construct request header
    api_endpoint = api_endpoint_from_url(request_url)
    request_header = {"Authorization": f"Bearer {api_key}"}
    # use api-key header for Azure deployments
    if "/deployments" in request_url:
        request_header = {"api-key": f"{api_key}"}

    # initialize trackers
    queue_of_requests_to_retry = asyncio.Queue()
    task_id_generator = (
        task_id_generator_function()
    )  # generates integer IDs of 0, 1, 2, ...
    status_tracker = (
        StatusTracker()
    )  # single instance to track a collection of variables
    next_request = None  # variable to hold the next request to call

    # initialize available capacity counts
    available_request_capacity = max_requests_per_minute
    available_token_capacity = max_tokens_per_minute
    last_update_time = time.time()

    # initialize flags
    file_not_finished = True  # after file is empty, we'll skip reading it
    logging.debug(f"Initialization complete.")

    # initialize file reading
    with open(requests_filepath) as file:
        # `requests` will provide requests one at a time
        requests = file.__iter__()
        logging.debug(f"File opened. Entering main loop")
        async with aiohttp.ClientSession() as session:  # Initialize ClientSession here
            while True:
                # get next request (if one is not already waiting for capacity)
                if next_request is None:
                    if not queue_of_requests_to_retry.empty():
                        next_request = queue_of_requests_to_retry.get_nowait()
                        logging.debug(
                            f"Retrying request {next_request.task_id}: {next_request}"
                        )
                    elif file_not_finished:
                        try:
                            # get new request
                            request_json = json.loads(next(requests))
                            next_request = APIRequest(
                                task_id=next(task_id_generator),
                                request_json=request_json,
                                token_consumption=num_tokens_consumed_from_request(
                                    request_json, api_endpoint, token_encoding_name
                                ),
                                attempts_left=max_attempts,
                                metadata=request_json.pop("metadata", None),
                            )
                            status_tracker.num_tasks_started += 1
                            status_tracker.num_tasks_in_progress += 1
                            logging.debug(
                                f"Reading request {next_request.task_id}: {next_request}"
                            )
                        except StopIteration:
                            # if file runs out, set flag to stop reading it
                            logging.debug("Read file exhausted")
                            file_not_finished = False

                # update available capacity
                current_time = time.time()
                seconds_since_update = current_time - last_update_time
                available_request_capacity = min(
                    available_request_capacity
                    + max_requests_per_minute * seconds_since_update / 60.0,
                    max_requests_per_minute,
                )
                available_token_capacity = min(
                    available_token_capacity
                    + max_tokens_per_minute * seconds_since_update / 60.0,
                    max_tokens_per_minute,
                )
                last_update_time = current_time

                # if enough capacity available, call API
                if next_request:
                    next_request_tokens = next_request.token_consumption
                    if (
                        available_request_capacity >= 1
                        and available_token_capacity >= next_request_tokens
                    ):
                        # update counters
                        available_request_capacity -= 1
                        available_token_capacity -= next_request_tokens
                        next_request.attempts_left -= 1

                        # call API
                        asyncio.create_task(
                            next_request.call_api(
                                session=session,
                                request_url=request_url,
                                request_header=request_header,
                                retry_queue=queue_of_requests_to_retry,
                                save_filepath=save_filepath,
                                status_tracker=status_tracker,
                            )
                        )
                        next_request = None  # reset next_request to empty

                # if all tasks are finished, break
                if status_tracker.num_tasks_in_progress == 0:
                    break

                # main loop sleeps briefly so concurrent tasks can run
                await asyncio.sleep(seconds_to_sleep_each_loop)

                # if a rate limit error was hit recently, pause to cool down
                seconds_since_rate_limit_error = (
                    time.time() - status_tracker.time_of_last_rate_limit_error
                )
                if (
                    seconds_since_rate_limit_error
                    < seconds_to_pause_after_rate_limit_error
                ):
                    remaining_seconds_to_pause = (
                        seconds_to_pause_after_rate_limit_error
                        - seconds_since_rate_limit_error
                    )
                    await asyncio.sleep(remaining_seconds_to_pause)
                    # ^e.g., if pause is 15 seconds and final limit was hit 5 seconds ago
                    logging.warn(
                        f"Pausing to cool down until {time.ctime(status_tracker.time_of_last_rate_limit_error + seconds_to_pause_after_rate_limit_error)}"
                    )

        # after finishing, log final status
        logging.info(
            f"""Parallel processing complete. Results saved to {save_filepath}"""
        )
        if status_tracker.num_tasks_failed > 0:
            logging.warning(
                f"{status_tracker.num_tasks_failed} / {status_tracker.num_tasks_started} requests failed. Errors logged to {save_filepath}."
            )
        if status_tracker.num_rate_limit_errors > 0:
            logging.warning(
                f"{status_tracker.num_rate_limit_errors} rate limit errors received. Consider running at a lower rate."
            )


# dataclasses


@dataclass
class StatusTracker:
    """Stores metadata about the script's progress. Only one instance is created."""

    num_tasks_started: int = 0
    num_tasks_in_progress: int = 0  # script ends when this reaches 0
    num_tasks_succeeded: int = 0
    num_tasks_failed: int = 0
    num_rate_limit_errors: int = 0
    num_api_errors: int = 0  # excluding rate limit errors, counted above
    num_other_errors: int = 0
    time_of_last_rate_limit_error: int = 0  # used to cool off after hitting rate limits


@dataclass
class APIRequest:
    """Stores an API request's inputs, outputs, and other metadata. Contains a method to make an API call."""

    task_id: int
    request_json: dict
    token_consumption: int
    attempts_left: int
    metadata: dict
    result: list = field(default_factory=list)

    async def call_api(
        self,
        session: aiohttp.ClientSession,
        request_url: str,
        request_header: dict,
        retry_queue: asyncio.Queue,
        save_filepath: str,
        status_tracker: StatusTracker,
    ):
        """Calls the OpenAI API and saves results."""
        logging.info(f"Starting request #{self.task_id}")
        error = None
        try:
            async with session.post(
                url=request_url, headers=request_header, json=self.request_json
            ) as response:
                response = await response.json()
            if "error" in response:
                logging.warning(
                    f"Request {self.task_id} failed with error {response['error']}"
                )
                status_tracker.num_api_errors += 1
                error = response
                if "Rate limit" in response["error"].get("message", ""):
                    status_tracker.time_of_last_rate_limit_error = time.time()
                    status_tracker.num_rate_limit_errors += 1
                    status_tracker.num_api_errors -= (
                        1  # rate limit errors are counted separately
                    )

        except (
            Exception
        ) as e:  # catching naked exceptions is bad practice, but in this case we'll log & save them
            logging.warning(f"Request {self.task_id} failed with Exception {e}")
            status_tracker.num_other_errors += 1
            error = e
        if error:
            self.result.append(error)
            if self.attempts_left:
                retry_queue.put_nowait(self)
            else:
                logging.error(
                    f"Request {self.request_json} failed after all attempts. Saving errors: {self.result}"
                )
                data = (
                    [self.request_json, [str(e) for e in self.result], self.metadata]
                    if self.metadata
                    else [self.request_json, [str(e) for e in self.result]]
                )
                append_to_jsonl(data, save_filepath)
                status_tracker.num_tasks_in_progress -= 1
                status_tracker.num_tasks_failed += 1
        else:
            data = (
                [self.request_json, response, self.metadata]
                if self.metadata
                else [self.request_json, response]
            )
            append_to_jsonl(data, save_filepath)
            status_tracker.num_tasks_in_progress -= 1
            status_tracker.num_tasks_succeeded += 1
            logging.debug(f"Request {self.task_id} saved to {save_filepath}")


# functions


def api_endpoint_from_url(request_url):
    """Extract the API endpoint from the request URL."""
    match = re.search("^https://[^/]+/v\\d+/(.+)$", request_url)
    if match is None:
        # for Azure OpenAI deployment urls
        match = re.search(
            r"^https://[^/]+/openai/deployments/[^/]+/(.+?)(\?|$)", request_url
        )
    return match[1]


def append_to_jsonl(data, filename: str) -> None:
    """Append a json payload to the end of a jsonl file."""
    json_string = json.dumps(data)
    with open(filename, "a") as f:
        f.write(json_string + "\n")


def num_tokens_consumed_from_request(
    request_json: dict,
    api_endpoint: str,
    token_encoding_name: str,
):
    """Count the number of tokens in the request. Only supports completion and embedding requests."""
    encoding = tiktoken.get_encoding(token_encoding_name)
    # if completions request, tokens = prompt + n * max_tokens
    if api_endpoint.endswith("completions"):
        max_tokens = request_json.get("max_tokens", 15)
        n = request_json.get("n", 1)
        completion_tokens = n * max_tokens

        # chat completions
        if api_endpoint.startswith("chat/"):
            num_tokens = 0
            for message in request_json["messages"]:
                num_tokens += 4  # every message follows <im_start>{role/name}\n{content}<im_end>\n
                for key, value in message.items():
                    num_tokens += len(encoding.encode(value))
                    if key == "name":  # if there's a name, the role is omitted
                        num_tokens -= 1  # role is always required and always 1 token
            num_tokens += 2  # every reply is primed with <im_start>assistant
            return num_tokens + completion_tokens
        # normal completions
        else:
            prompt = request_json["prompt"]
            if isinstance(prompt, str):  # single prompt
                prompt_tokens = len(encoding.encode(prompt))
                num_tokens = prompt_tokens + completion_tokens
                return num_tokens
            elif isinstance(prompt, list):  # multiple prompts
                prompt_tokens = sum([len(encoding.encode(p)) for p in prompt])
                num_tokens = prompt_tokens + completion_tokens * len(prompt)
                return num_tokens
            else:
                raise TypeError(
                    'Expecting either string or list of strings for "prompt" field in completion request'
                )
    # if embeddings request, tokens = input tokens
    elif api_endpoint == "embeddings":
        input = request_json["input"]
        if isinstance(input, str):  # single input
            num_tokens = len(encoding.encode(input))
            return num_tokens
        elif isinstance(input, list):  # multiple inputs
            num_tokens = sum([len(encoding.encode(i)) for i in input])
            return num_tokens
        else:
            raise TypeError(
                'Expecting either string or list of strings for "inputs" field in embedding request'
            )
    # more logic needed to support other API calls (e.g., edits, inserts, DALL-E)
    else:
        raise NotImplementedError(
            f'API endpoint "{api_endpoint}" not implemented in this script'
        )


def task_id_generator_function():
    """Generate integers 0, 1, 2, and so on."""
    task_id = 0
    while True:
        yield task_id
        task_id += 1


# run script


# if __name__ == "__main__":
#     # parse command line arguments
#     parser = argparse.ArgumentParser()
#     parser.add_argument("--requests_filepath")
#     parser.add_argument("--save_filepath", default=None)
#     parser.add_argument("--request_url", default="https://api.openai.com/v1/completions")
#     parser.add_argument("--api_key", default=os.getenv("OPENAI_API_KEY"))
#     parser.add_argument("--max_requests_per_minute", type=int, default=3_000 * 0.5)
#     parser.add_argument("--max_tokens_per_minute", type=int, default=250_000 * 0.5)
#     # parser.add_argument("--token_encoding_name", default="cl100k_base")
#     parser.add_argument("--max_attempts", type=int, default=5)
#     parser.add_argument("--logging_level", default=logging.INFO)
#     args = parser.parse_args()

#     if args.save_filepath is None:
#         args.save_filepath = args.requests_filepath.replace(".jsonl", "_results.jsonl")

#     # run script
#     asyncio.run(
#         process_api_requests_from_file(
#             requests_filepath=args.requests_filepath,
#             save_filepath=args.save_filepath,
#             request_url=args.request_url,
#             api_key=args.api_key,
#             max_requests_per_minute=float(args.max_requests_per_minute),
#             max_tokens_per_minute=float(args.max_tokens_per_minute),
#             token_encoding_name=args.token_encoding_name,
#             max_attempts=int(args.max_attempts),
#             logging_level=int(args.logging_level),
#         )
#     )


"""
APPENDIX

The example requests file at openai-cookbook/examples/data/example_requests_to_parallel_process.jsonl contains 10,000 requests to text-embedding-3-small.

It was generated with the following code:

```python
import json

filename = "data/example_requests_to_parallel_process.jsonl"
n_requests = 10_000
jobs = [{"model": "text-embedding-3-small", "input": str(x) + "\n"} for x in range(n_requests)]
with open(filename, "w") as f:
    for job in jobs:
        json_string = json.dumps(job)
        f.write(json_string + "\n")
```

As with all jsonl files, take care that newlines in the content are properly escaped (json.dumps does this automatically).
"""
# Out:
# '\nAPPENDIX\n\nThe example requests file at openai-cookbook/examples/data/example_requests_to_parallel_process.jsonl contains 10,000 requests to text-embedding-3-small.\n\nIt was generated with the following code:\n\n```python\nimport json\n\nfilename = "data/example_requests_to_parallel_process.jsonl"\nn_requests = 10_000\njobs = [{"model": "text-embedding-3-small", "input": str(x) + "\n"} for x in range(n_requests)]\nwith open(filename, "w") as f:\n    for job in jobs:\n        json_string = json.dumps(job)\n        f.write(json_string + "\n")\n```\n\nAs with all jsonl files, take care that newlines in the content are properly escaped (json.dumps does this automatically).\n'

# %%
import json
import os

path = os.path.abspath('../Dataset/data')
print(path)

model_name = 'gpt-3.5-turbo'

segments_filename = '/segments_filtered.json'
full_path = path + segments_filename
# Out:
# /home/donovan/code/cse447/Audio-to-Language-Alignment-via-Musical-Sentiment/Dataset/data

# %%
with open(path + segments_filename, 'r') as f:
    segments = json.load(f)
    num_data_points = len(segments)
    # num_data_points = 517

batch_size = 30

print("Number of data points: ", num_data_points)
print("Batch size: ", batch_size)
# Out:
# Number of data points:  53683
# Batch size:  30

# %%
jobs = []
num_descriptions = 0
first_numbers = set([])
all_lines = []

with open(path + segments_filename, 'r') as f:
    segments = json.load(f)

    for i in range(0, num_data_points, batch_size):
        if i + batch_size >= num_data_points:
            batch = segments[i:num_data_points]
        else:
            batch = segments[i:i+batch_size]


        for j, _ in enumerate(batch):
            first_numbers.add(j + i)

        lines = [f"SEGMENT#{j + i: 06d}: " + segment['line'] for j, segment in enumerate(batch)]
        print(f'Length of the {i // batch_size}th batch: {len(lines)}')
        all_lines.extend(lines)

        prompt = f"Here are {len(lines)} lines of lyrics from songs: {lines}.  Generate a 1 sentence description of the sentiment for each line. DO NOT make it conversational. Be turse. Format the output as a JSON list of the form [<response 1>, ..., <response n> ] (not a dictionary). Start each description with: \"SEGMENT#<segment num>; The lyrics are\" ."

        messages = [
                    {"role": "user"},
                    ]
        messages[0]['content'] = prompt
        jobs.append({"model": model_name, "messages": messages})
        num_descriptions += len(lines)

my_range = set(range(0, num_data_points))

for number in my_range:
    if number not in first_numbers:
        print(number)



print(f'Number of requests: {len(jobs)}')
print(f'Number of descriptions: {num_descriptions}')
# Out:
# Length of the 0th batch: 30
# Length of the 1th batch: 30
# Length of the 2th batch: 30
# Length of the 3th batch: 30
# Length of the 4th batch: 30
# Length of the 5th batch: 30
# Length of the 6th batch: 30
# Length of the 7th batch: 30
# Length of the 8th batch: 30
# Length of the 9th batch: 30
# Length of the 10th batch: 30
# Length of the 11th batch: 30
# Length of the 12th batch: 30
# Length of the 13th batch: 30
# Length of the 14th batch: 30
# Length of the 15th batch: 30
# Length of the 16th batch: 30
# Length of the 17th batch: 30
# Length of the 18th batch: 30
# Length of the 19th batch: 30
# Length of the 20th batch: 30
# Length of the 21th batch: 30
# Length of the 22th batch: 30
# Length of the 23th batch: 30
# Length of the 24th batch: 30
# Length of the 25th batch: 30
# Length of the 26th batch: 30
# Length of the 27th batch: 30
# Length of the 28th batch: 30
# Length of the 29th batch: 30
# Length of the 30th batch: 30
# Length of the 31th batch: 30
# Length of the 32th batch: 30
# Length of the 33th batch: 30
# Length of the 34th batch: 30
# Length of the 35th batch: 30
# Length of the 36th batch: 30
# Length of the 37th batch: 30
# Length of the 38th batch: 30
# Length of the 39th batch: 30
# Length of the 40th batch: 30
# Length of the 41th batch: 30
# Length of the 42th batch: 30
# Length of the 43th batch: 30
# Length of the 44th batch: 30
# Length of the 45th batch: 30
# Length of the 46th batch: 30
# Length of the 47th batch: 30
# Length of the 48th batch: 30
# Length of the 49th batch: 30
# Length of the 50th batch: 30
# Length of the 51th batch: 30
# Length of the 52th batch: 30
# Length of the 53th batch: 30
# Length of the 54th batch: 30
# Length of the 55th batch: 30
# Length of the 56th batch: 30
# Length of the 57th batch: 30
# Length of the 58th batch: 30
# Length of the 59th batch: 30
# Length of the 60th batch: 30
# Length of the 61th batch: 30
# Length of the 62th batch: 30
# Length of the 63th batch: 30
# Length of the 64th batch: 30
# Length of the 65th batch: 30
# Length of the 66th batch: 30
# Length of the 67th batch: 30
# Length of the 68th batch: 30
# Length of the 69th batch: 30
# Length of the 70th batch: 30
# Length of the 71th batch: 30
# Length of the 72th batch: 30
# Length of the 73th batch: 30
# Length of the 74th batch: 30
# Length of the 75th batch: 30
# Length of the 76th batch: 30
# Length of the 77th batch: 30
# Length of the 78th batch: 30
# Length of the 79th batch: 30
# Length of the 80th batch: 30
# Length of the 81th batch: 30
# Length of the 82th batch: 30
# Length of the 83th batch: 30
# Length of the 84th batch: 30
# Length of the 85th batch: 30
# Length of the 86th batch: 30
# Length of the 87th batch: 30
# Length of the 88th batch: 30
# Length of the 89th batch: 30
# Length of the 90th batch: 30
# Length of the 91th batch: 30
# Length of the 92th batch: 30
# Length of the 93th batch: 30
# Length of the 94th batch: 30
# Length of the 95th batch: 30
# Length of the 96th batch: 30
# Length of the 97th batch: 30
# Length of the 98th batch: 30
# Length of the 99th batch: 30
# Length of the 100th batch: 30
# Length of the 101th batch: 30
# Length of the 102th batch: 30
# Length of the 103th batch: 30
# Length of the 104th batch: 30
# Length of the 105th batch: 30
# Length of the 106th batch: 30
# Length of the 107th batch: 30
# Length of the 108th batch: 30
# Length of the 109th batch: 30
# Length of the 110th batch: 30
# Length of the 111th batch: 30
# Length of the 112th batch: 30
# Length of the 113th batch: 30
# Length of the 114th batch: 30
# Length of the 115th batch: 30
# Length of the 116th batch: 30
# Length of the 117th batch: 30
# Length of the 118th batch: 30
# Length of the 119th batch: 30
# Length of the 120th batch: 30
# Length of the 121th batch: 30
# Length of the 122th batch: 30
# Length of the 123th batch: 30
# Length of the 124th batch: 30
# Length of the 125th batch: 30
# Length of the 126th batch: 30
# Length of the 127th batch: 30
# Length of the 128th batch: 30
# Length of the 129th batch: 30
# Length of the 130th batch: 30
# Length of the 131th batch: 30
# Length of the 132th batch: 30
# Length of the 133th batch: 30
# Length of the 134th batch: 30
# Length of the 135th batch: 30
# Length of the 136th batch: 30
# Length of the 137th batch: 30
# Length of the 138th batch: 30
# Length of the 139th batch: 30
# Length of the 140th batch: 30
# Length of the 141th batch: 30
# Length of the 142th batch: 30
# Length of the 143th batch: 30
# Length of the 144th batch: 30
# Length of the 145th batch: 30
# Length of the 146th batch: 30
# Length of the 147th batch: 30
# Length of the 148th batch: 30
# Length of the 149th batch: 30
# Length of the 150th batch: 30
# Length of the 151th batch: 30
# Length of the 152th batch: 30
# Length of the 153th batch: 30
# Length of the 154th batch: 30
# Length of the 155th batch: 30
# Length of the 156th batch: 30
# Length of the 157th batch: 30
# Length of the 158th batch: 30
# Length of the 159th batch: 30
# Length of the 160th batch: 30
# Length of the 161th batch: 30
# Length of the 162th batch: 30
# Length of the 163th batch: 30
# Length of the 164th batch: 30
# Length of the 165th batch: 30
# Length of the 166th batch: 30
# Length of the 167th batch: 30
# Length of the 168th batch: 30
# Length of the 169th batch: 30
# Length of the 170th batch: 30
# Length of the 171th batch: 30
# Length of the 172th batch: 30
# Length of the 173th batch: 30
# Length of the 174th batch: 30
# Length of the 175th batch: 30
# Length of the 176th batch: 30
# Length of the 177th batch: 30
# Length of the 178th batch: 30
# Length of the 179th batch: 30
# Length of the 180th batch: 30
# Length of the 181th batch: 30
# Length of the 182th batch: 30
# Length of the 183th batch: 30
# Length of the 184th batch: 30
# Length of the 185th batch: 30
# Length of the 186th batch: 30
# Length of the 187th batch: 30
# Length of the 188th batch: 30
# Length of the 189th batch: 30
# Length of the 190th batch: 30
# Length of the 191th batch: 30
# Length of the 192th batch: 30
# Length of the 193th batch: 30
# Length of the 194th batch: 30
# Length of the 195th batch: 30
# Length of the 196th batch: 30
# Length of the 197th batch: 30
# Length of the 198th batch: 30
# Length of the 199th batch: 30
# Length of the 200th batch: 30
# Length of the 201th batch: 30
# Length of the 202th batch: 30
# Length of the 203th batch: 30
# Length of the 204th batch: 30
# Length of the 205th batch: 30
# Length of the 206th batch: 30
# Length of the 207th batch: 30
# Length of the 208th batch: 30
# Length of the 209th batch: 30
# Length of the 210th batch: 30
# Length of the 211th batch: 30
# Length of the 212th batch: 30
# Length of the 213th batch: 30
# Length of the 214th batch: 30
# Length of the 215th batch: 30
# Length of the 216th batch: 30
# Length of the 217th batch: 30
# Length of the 218th batch: 30
# Length of the 219th batch: 30
# Length of the 220th batch: 30
# Length of the 221th batch: 30
# Length of the 222th batch: 30
# Length of the 223th batch: 30
# Length of the 224th batch: 30
# Length of the 225th batch: 30
# Length of the 226th batch: 30
# Length of the 227th batch: 30
# Length of the 228th batch: 30
# Length of the 229th batch: 30
# Length of the 230th batch: 30
# Length of the 231th batch: 30
# Length of the 232th batch: 30
# Length of the 233th batch: 30
# Length of the 234th batch: 30
# Length of the 235th batch: 30
# Length of the 236th batch: 30
# Length of the 237th batch: 30
# Length of the 238th batch: 30
# Length of the 239th batch: 30
# Length of the 240th batch: 30
# Length of the 241th batch: 30
# Length of the 242th batch: 30
# Length of the 243th batch: 30
# Length of the 244th batch: 30
# Length of the 245th batch: 30
# Length of the 246th batch: 30
# Length of the 247th batch: 30
# Length of the 248th batch: 30
# Length of the 249th batch: 30
# Length of the 250th batch: 30
# Length of the 251th batch: 30
# Length of the 252th batch: 30
# Length of the 253th batch: 30
# Length of the 254th batch: 30
# Length of the 255th batch: 30
# Length of the 256th batch: 30
# Length of the 257th batch: 30
# Length of the 258th batch: 30
# Length of the 259th batch: 30
# Length of the 260th batch: 30
# Length of the 261th batch: 30
# Length of the 262th batch: 30
# Length of the 263th batch: 30
# Length of the 264th batch: 30
# Length of the 265th batch: 30
# Length of the 266th batch: 30
# Length of the 267th batch: 30
# Length of the 268th batch: 30
# Length of the 269th batch: 30
# Length of the 270th batch: 30
# Length of the 271th batch: 30
# Length of the 272th batch: 30
# Length of the 273th batch: 30
# Length of the 274th batch: 30
# Length of the 275th batch: 30
# Length of the 276th batch: 30
# Length of the 277th batch: 30
# Length of the 278th batch: 30
# Length of the 279th batch: 30
# Length of the 280th batch: 30
# Length of the 281th batch: 30
# Length of the 282th batch: 30
# Length of the 283th batch: 30
# Length of the 284th batch: 30
# Length of the 285th batch: 30
# Length of the 286th batch: 30
# Length of the 287th batch: 30
# Length of the 288th batch: 30
# Length of the 289th batch: 30
# Length of the 290th batch: 30
# Length of the 291th batch: 30
# Length of the 292th batch: 30
# Length of the 293th batch: 30
# Length of the 294th batch: 30
# Length of the 295th batch: 30
# Length of the 296th batch: 30
# Length of the 297th batch: 30
# Length of the 298th batch: 30
# Length of the 299th batch: 30
# Length of the 300th batch: 30
# Length of the 301th batch: 30
# Length of the 302th batch: 30
# Length of the 303th batch: 30
# Length of the 304th batch: 30
# Length of the 305th batch: 30
# Length of the 306th batch: 30
# Length of the 307th batch: 30
# Length of the 308th batch: 30
# Length of the 309th batch: 30
# Length of the 310th batch: 30
# Length of the 311th batch: 30
# Length of the 312th batch: 30
# Length of the 313th batch: 30
# Length of the 314th batch: 30
# Length of the 315th batch: 30
# Length of the 316th batch: 30
# Length of the 317th batch: 30
# Length of the 318th batch: 30
# Length of the 319th batch: 30
# Length of the 320th batch: 30
# Length of the 321th batch: 30
# Length of the 322th batch: 30
# Length of the 323th batch: 30
# Length of the 324th batch: 30
# Length of the 325th batch: 30
# Length of the 326th batch: 30
# Length of the 327th batch: 30
# Length of the 328th batch: 30
# Length of the 329th batch: 30
# Length of the 330th batch: 30
# Length of the 331th batch: 30
# Length of the 332th batch: 30
# Length of the 333th batch: 30
# Length of the 334th batch: 30
# Length of the 335th batch: 30
# Length of the 336th batch: 30
# Length of the 337th batch: 30
# Length of the 338th batch: 30
# Length of the 339th batch: 30
# Length of the 340th batch: 30
# Length of the 341th batch: 30
# Length of the 342th batch: 30
# Length of the 343th batch: 30
# Length of the 344th batch: 30
# Length of the 345th batch: 30
# Length of the 346th batch: 30
# Length of the 347th batch: 30
# Length of the 348th batch: 30
# Length of the 349th batch: 30
# Length of the 350th batch: 30
# Length of the 351th batch: 30
# Length of the 352th batch: 30
# Length of the 353th batch: 30
# Length of the 354th batch: 30
# Length of the 355th batch: 30
# Length of the 356th batch: 30
# Length of the 357th batch: 30
# Length of the 358th batch: 30
# Length of the 359th batch: 30
# Length of the 360th batch: 30
# Length of the 361th batch: 30
# Length of the 362th batch: 30
# Length of the 363th batch: 30
# Length of the 364th batch: 30
# Length of the 365th batch: 30
# Length of the 366th batch: 30
# Length of the 367th batch: 30
# Length of the 368th batch: 30
# Length of the 369th batch: 30
# Length of the 370th batch: 30
# Length of the 371th batch: 30
# Length of the 372th batch: 30
# Length of the 373th batch: 30
# Length of the 374th batch: 30
# Length of the 375th batch: 30
# Length of the 376th batch: 30
# Length of the 377th batch: 30
# Length of the 378th batch: 30
# Length of the 379th batch: 30
# Length of the 380th batch: 30
# Length of the 381th batch: 30
# Length of the 382th batch: 30
# Length of the 383th batch: 30
# Length of the 384th batch: 30
# Length of the 385th batch: 30
# Length of the 386th batch: 30
# Length of the 387th batch: 30
# Length of the 388th batch: 30
# Length of the 389th batch: 30
# Length of the 390th batch: 30
# Length of the 391th batch: 30
# Length of the 392th batch: 30
# Length of the 393th batch: 30
# Length of the 394th batch: 30
# Length of the 395th batch: 30
# Length of the 396th batch: 30
# Length of the 397th batch: 30
# Length of the 398th batch: 30
# Length of the 399th batch: 30
# Length of the 400th batch: 30
# Length of the 401th batch: 30
# Length of the 402th batch: 30
# Length of the 403th batch: 30
# Length of the 404th batch: 30
# Length of the 405th batch: 30
# Length of the 406th batch: 30
# Length of the 407th batch: 30
# Length of the 408th batch: 30
# Length of the 409th batch: 30
# Length of the 410th batch: 30
# Length of the 411th batch: 30
# Length of the 412th batch: 30
# Length of the 413th batch: 30
# Length of the 414th batch: 30
# Length of the 415th batch: 30
# Length of the 416th batch: 30
# Length of the 417th batch: 30
# Length of the 418th batch: 30
# Length of the 419th batch: 30
# Length of the 420th batch: 30
# Length of the 421th batch: 30
# Length of the 422th batch: 30
# Length of the 423th batch: 30
# Length of the 424th batch: 30
# Length of the 425th batch: 30
# Length of the 426th batch: 30
# Length of the 427th batch: 30
# Length of the 428th batch: 30
# Length of the 429th batch: 30
# Length of the 430th batch: 30
# Length of the 431th batch: 30
# Length of the 432th batch: 30
# Length of the 433th batch: 30
# Length of the 434th batch: 30
# Length of the 435th batch: 30
# Length of the 436th batch: 30
# Length of the 437th batch: 30
# Length of the 438th batch: 30
# Length of the 439th batch: 30
# Length of the 440th batch: 30
# Length of the 441th batch: 30
# Length of the 442th batch: 30
# Length of the 443th batch: 30
# Length of the 444th batch: 30
# Length of the 445th batch: 30
# Length of the 446th batch: 30
# Length of the 447th batch: 30
# Length of the 448th batch: 30
# Length of the 449th batch: 30
# Length of the 450th batch: 30
# Length of the 451th batch: 30
# Length of the 452th batch: 30
# Length of the 453th batch: 30
# Length of the 454th batch: 30
# Length of the 455th batch: 30
# Length of the 456th batch: 30
# Length of the 457th batch: 30
# Length of the 458th batch: 30
# Length of the 459th batch: 30
# Length of the 460th batch: 30
# Length of the 461th batch: 30
# Length of the 462th batch: 30
# Length of the 463th batch: 30
# Length of the 464th batch: 30
# Length of the 465th batch: 30
# Length of the 466th batch: 30
# Length of the 467th batch: 30
# Length of the 468th batch: 30
# Length of the 469th batch: 30
# Length of the 470th batch: 30
# Length of the 471th batch: 30
# Length of the 472th batch: 30
# Length of the 473th batch: 30
# Length of the 474th batch: 30
# Length of the 475th batch: 30
# Length of the 476th batch: 30
# Length of the 477th batch: 30
# Length of the 478th batch: 30
# Length of the 479th batch: 30
# Length of the 480th batch: 30
# Length of the 481th batch: 30
# Length of the 482th batch: 30
# Length of the 483th batch: 30
# Length of the 484th batch: 30
# Length of the 485th batch: 30
# Length of the 486th batch: 30
# Length of the 487th batch: 30
# Length of the 488th batch: 30
# Length of the 489th batch: 30
# Length of the 490th batch: 30
# Length of the 491th batch: 30
# Length of the 492th batch: 30
# Length of the 493th batch: 30
# Length of the 494th batch: 30
# Length of the 495th batch: 30
# Length of the 496th batch: 30
# Length of the 497th batch: 30
# Length of the 498th batch: 30
# Length of the 499th batch: 30
# Length of the 500th batch: 30
# Length of the 501th batch: 30
# Length of the 502th batch: 30
# Length of the 503th batch: 30
# Length of the 504th batch: 30
# Length of the 505th batch: 30
# Length of the 506th batch: 30
# Length of the 507th batch: 30
# Length of the 508th batch: 30
# Length of the 509th batch: 30
# Length of the 510th batch: 30
# Length of the 511th batch: 30
# Length of the 512th batch: 30
# Length of the 513th batch: 30
# Length of the 514th batch: 30
# Length of the 515th batch: 30
# Length of the 516th batch: 30
# Length of the 517th batch: 30
# Length of the 518th batch: 30
# Length of the 519th batch: 30
# Length of the 520th batch: 30
# Length of the 521th batch: 30
# Length of the 522th batch: 30
# Length of the 523th batch: 30
# Length of the 524th batch: 30
# Length of the 525th batch: 30
# Length of the 526th batch: 30
# Length of the 527th batch: 30
# Length of the 528th batch: 30
# Length of the 529th batch: 30
# Length of the 530th batch: 30
# Length of the 531th batch: 30
# Length of the 532th batch: 30
# Length of the 533th batch: 30
# Length of the 534th batch: 30
# Length of the 535th batch: 30
# Length of the 536th batch: 30
# Length of the 537th batch: 30
# Length of the 538th batch: 30
# Length of the 539th batch: 30
# Length of the 540th batch: 30
# Length of the 541th batch: 30
# Length of the 542th batch: 30
# Length of the 543th batch: 30
# Length of the 544th batch: 30
# Length of the 545th batch: 30
# Length of the 546th batch: 30
# Length of the 547th batch: 30
# Length of the 548th batch: 30
# Length of the 549th batch: 30
# Length of the 550th batch: 30
# Length of the 551th batch: 30
# Length of the 552th batch: 30
# Length of the 553th batch: 30
# Length of the 554th batch: 30
# Length of the 555th batch: 30
# Length of the 556th batch: 30
# Length of the 557th batch: 30
# Length of the 558th batch: 30
# Length of the 559th batch: 30
# Length of the 560th batch: 30
# Length of the 561th batch: 30
# Length of the 562th batch: 30
# Length of the 563th batch: 30
# Length of the 564th batch: 30
# Length of the 565th batch: 30
# Length of the 566th batch: 30
# Length of the 567th batch: 30
# Length of the 568th batch: 30
# Length of the 569th batch: 30
# Length of the 570th batch: 30
# Length of the 571th batch: 30
# Length of the 572th batch: 30
# Length of the 573th batch: 30
# Length of the 574th batch: 30
# Length of the 575th batch: 30
# Length of the 576th batch: 30
# Length of the 577th batch: 30
# Length of the 578th batch: 30
# Length of the 579th batch: 30
# Length of the 580th batch: 30
# Length of the 581th batch: 30
# Length of the 582th batch: 30
# Length of the 583th batch: 30
# Length of the 584th batch: 30
# Length of the 585th batch: 30
# Length of the 586th batch: 30
# Length of the 587th batch: 30
# Length of the 588th batch: 30
# Length of the 589th batch: 30
# Length of the 590th batch: 30
# Length of the 591th batch: 30
# Length of the 592th batch: 30
# Length of the 593th batch: 30
# Length of the 594th batch: 30
# Length of the 595th batch: 30
# Length of the 596th batch: 30
# Length of the 597th batch: 30
# Length of the 598th batch: 30
# Length of the 599th batch: 30
# Length of the 600th batch: 30
# Length of the 601th batch: 30
# Length of the 602th batch: 30
# Length of the 603th batch: 30
# Length of the 604th batch: 30
# Length of the 605th batch: 30
# Length of the 606th batch: 30
# Length of the 607th batch: 30
# Length of the 608th batch: 30
# Length of the 609th batch: 30
# Length of the 610th batch: 30
# Length of the 611th batch: 30
# Length of the 612th batch: 30
# Length of the 613th batch: 30
# Length of the 614th batch: 30
# Length of the 615th batch: 30
# Length of the 616th batch: 30
# Length of the 617th batch: 30
# Length of the 618th batch: 30
# Length of the 619th batch: 30
# Length of the 620th batch: 30
# Length of the 621th batch: 30
# Length of the 622th batch: 30
# Length of the 623th batch: 30
# Length of the 624th batch: 30
# Length of the 625th batch: 30
# Length of the 626th batch: 30
# Length of the 627th batch: 30
# Length of the 628th batch: 30
# Length of the 629th batch: 30
# Length of the 630th batch: 30
# Length of the 631th batch: 30
# Length of the 632th batch: 30
# Length of the 633th batch: 30
# Length of the 634th batch: 30
# Length of the 635th batch: 30
# Length of the 636th batch: 30
# Length of the 637th batch: 30
# Length of the 638th batch: 30
# Length of the 639th batch: 30
# Length of the 640th batch: 30
# Length of the 641th batch: 30
# Length of the 642th batch: 30
# Length of the 643th batch: 30
# Length of the 644th batch: 30
# Length of the 645th batch: 30
# Length of the 646th batch: 30
# Length of the 647th batch: 30
# Length of the 648th batch: 30
# Length of the 649th batch: 30
# Length of the 650th batch: 30
# Length of the 651th batch: 30
# Length of the 652th batch: 30
# Length of the 653th batch: 30
# Length of the 654th batch: 30
# Length of the 655th batch: 30
# Length of the 656th batch: 30
# Length of the 657th batch: 30
# Length of the 658th batch: 30
# Length of the 659th batch: 30
# Length of the 660th batch: 30
# Length of the 661th batch: 30
# Length of the 662th batch: 30
# Length of the 663th batch: 30
# Length of the 664th batch: 30
# Length of the 665th batch: 30
# Length of the 666th batch: 30
# Length of the 667th batch: 30
# Length of the 668th batch: 30
# Length of the 669th batch: 30
# Length of the 670th batch: 30
# Length of the 671th batch: 30
# Length of the 672th batch: 30
# Length of the 673th batch: 30
# Length of the 674th batch: 30
# Length of the 675th batch: 30
# Length of the 676th batch: 30
# Length of the 677th batch: 30
# Length of the 678th batch: 30
# Length of the 679th batch: 30
# Length of the 680th batch: 30
# Length of the 681th batch: 30
# Length of the 682th batch: 30
# Length of the 683th batch: 30
# Length of the 684th batch: 30
# Length of the 685th batch: 30
# Length of the 686th batch: 30
# Length of the 687th batch: 30
# Length of the 688th batch: 30
# Length of the 689th batch: 30
# Length of the 690th batch: 30
# Length of the 691th batch: 30
# Length of the 692th batch: 30
# Length of the 693th batch: 30
# Length of the 694th batch: 30
# Length of the 695th batch: 30
# Length of the 696th batch: 30
# Length of the 697th batch: 30
# Length of the 698th batch: 30
# Length of the 699th batch: 30
# Length of the 700th batch: 30
# Length of the 701th batch: 30
# Length of the 702th batch: 30
# Length of the 703th batch: 30
# Length of the 704th batch: 30
# Length of the 705th batch: 30
# Length of the 706th batch: 30
# Length of the 707th batch: 30
# Length of the 708th batch: 30
# Length of the 709th batch: 30
# Length of the 710th batch: 30
# Length of the 711th batch: 30
# Length of the 712th batch: 30
# Length of the 713th batch: 30
# Length of the 714th batch: 30
# Length of the 715th batch: 30
# Length of the 716th batch: 30
# Length of the 717th batch: 30
# Length of the 718th batch: 30
# Length of the 719th batch: 30
# Length of the 720th batch: 30
# Length of the 721th batch: 30
# Length of the 722th batch: 30
# Length of the 723th batch: 30
# Length of the 724th batch: 30
# Length of the 725th batch: 30
# Length of the 726th batch: 30
# Length of the 727th batch: 30
# Length of the 728th batch: 30
# Length of the 729th batch: 30
# Length of the 730th batch: 30
# Length of the 731th batch: 30
# Length of the 732th batch: 30
# Length of the 733th batch: 30
# Length of the 734th batch: 30
# Length of the 735th batch: 30
# Length of the 736th batch: 30
# Length of the 737th batch: 30
# Length of the 738th batch: 30
# Length of the 739th batch: 30
# Length of the 740th batch: 30
# Length of the 741th batch: 30
# Length of the 742th batch: 30
# Length of the 743th batch: 30
# Length of the 744th batch: 30
# Length of the 745th batch: 30
# Length of the 746th batch: 30
# Length of the 747th batch: 30
# Length of the 748th batch: 30
# Length of the 749th batch: 30
# Length of the 750th batch: 30
# Length of the 751th batch: 30
# Length of the 752th batch: 30
# Length of the 753th batch: 30
# Length of the 754th batch: 30
# Length of the 755th batch: 30
# Length of the 756th batch: 30
# Length of the 757th batch: 30
# Length of the 758th batch: 30
# Length of the 759th batch: 30
# Length of the 760th batch: 30
# Length of the 761th batch: 30
# Length of the 762th batch: 30
# Length of the 763th batch: 30
# Length of the 764th batch: 30
# Length of the 765th batch: 30
# Length of the 766th batch: 30
# Length of the 767th batch: 30
# Length of the 768th batch: 30
# Length of the 769th batch: 30
# Length of the 770th batch: 30
# Length of the 771th batch: 30
# Length of the 772th batch: 30
# Length of the 773th batch: 30
# Length of the 774th batch: 30
# Length of the 775th batch: 30
# Length of the 776th batch: 30
# Length of the 777th batch: 30
# Length of the 778th batch: 30
# Length of the 779th batch: 30
# Length of the 780th batch: 30
# Length of the 781th batch: 30
# Length of the 782th batch: 30
# Length of the 783th batch: 30
# Length of the 784th batch: 30
# Length of the 785th batch: 30
# Length of the 786th batch: 30
# Length of the 787th batch: 30
# Length of the 788th batch: 30
# Length of the 789th batch: 30
# Length of the 790th batch: 30
# Length of the 791th batch: 30
# Length of the 792th batch: 30
# Length of the 793th batch: 30
# Length of the 794th batch: 30
# Length of the 795th batch: 30
# Length of the 796th batch: 30
# Length of the 797th batch: 30
# Length of the 798th batch: 30
# Length of the 799th batch: 30
# Length of the 800th batch: 30
# Length of the 801th batch: 30
# Length of the 802th batch: 30
# Length of the 803th batch: 30
# Length of the 804th batch: 30
# Length of the 805th batch: 30
# Length of the 806th batch: 30
# Length of the 807th batch: 30
# Length of the 808th batch: 30
# Length of the 809th batch: 30
# Length of the 810th batch: 30
# Length of the 811th batch: 30
# Length of the 812th batch: 30
# Length of the 813th batch: 30
# Length of the 814th batch: 30
# Length of the 815th batch: 30
# Length of the 816th batch: 30
# Length of the 817th batch: 30
# Length of the 818th batch: 30
# Length of the 819th batch: 30
# Length of the 820th batch: 30
# Length of the 821th batch: 30
# Length of the 822th batch: 30
# Length of the 823th batch: 30
# Length of the 824th batch: 30
# Length of the 825th batch: 30
# Length of the 826th batch: 30
# Length of the 827th batch: 30
# Length of the 828th batch: 30
# Length of the 829th batch: 30
# Length of the 830th batch: 30
# Length of the 831th batch: 30
# Length of the 832th batch: 30
# Length of the 833th batch: 30
# Length of the 834th batch: 30
# Length of the 835th batch: 30
# Length of the 836th batch: 30
# Length of the 837th batch: 30
# Length of the 838th batch: 30
# Length of the 839th batch: 30
# Length of the 840th batch: 30
# Length of the 841th batch: 30
# Length of the 842th batch: 30
# Length of the 843th batch: 30
# Length of the 844th batch: 30
# Length of the 845th batch: 30
# Length of the 846th batch: 30
# Length of the 847th batch: 30
# Length of the 848th batch: 30
# Length of the 849th batch: 30
# Length of the 850th batch: 30
# Length of the 851th batch: 30
# Length of the 852th batch: 30
# Length of the 853th batch: 30
# Length of the 854th batch: 30
# Length of the 855th batch: 30
# Length of the 856th batch: 30
# Length of the 857th batch: 30
# Length of the 858th batch: 30
# Length of the 859th batch: 30
# Length of the 860th batch: 30
# Length of the 861th batch: 30
# Length of the 862th batch: 30
# Length of the 863th batch: 30
# Length of the 864th batch: 30
# Length of the 865th batch: 30
# Length of the 866th batch: 30
# Length of the 867th batch: 30
# Length of the 868th batch: 30
# Length of the 869th batch: 30
# Length of the 870th batch: 30
# Length of the 871th batch: 30
# Length of the 872th batch: 30
# Length of the 873th batch: 30
# Length of the 874th batch: 30
# Length of the 875th batch: 30
# Length of the 876th batch: 30
# Length of the 877th batch: 30
# Length of the 878th batch: 30
# Length of the 879th batch: 30
# Length of the 880th batch: 30
# Length of the 881th batch: 30
# Length of the 882th batch: 30
# Length of the 883th batch: 30
# Length of the 884th batch: 30
# Length of the 885th batch: 30
# Length of the 886th batch: 30
# Length of the 887th batch: 30
# Length of the 888th batch: 30
# Length of the 889th batch: 30
# Length of the 890th batch: 30
# Length of the 891th batch: 30
# Length of the 892th batch: 30
# Length of the 893th batch: 30
# Length of the 894th batch: 30
# Length of the 895th batch: 30
# Length of the 896th batch: 30
# Length of the 897th batch: 30
# Length of the 898th batch: 30
# Length of the 899th batch: 30
# Length of the 900th batch: 30
# Length of the 901th batch: 30
# Length of the 902th batch: 30
# Length of the 903th batch: 30
# Length of the 904th batch: 30
# Length of the 905th batch: 30
# Length of the 906th batch: 30
# Length of the 907th batch: 30
# Length of the 908th batch: 30
# Length of the 909th batch: 30
# Length of the 910th batch: 30
# Length of the 911th batch: 30
# Length of the 912th batch: 30
# Length of the 913th batch: 30
# Length of the 914th batch: 30
# Length of the 915th batch: 30
# Length of the 916th batch: 30
# Length of the 917th batch: 30
# Length of the 918th batch: 30
# Length of the 919th batch: 30
# Length of the 920th batch: 30
# Length of the 921th batch: 30
# Length of the 922th batch: 30
# Length of the 923th batch: 30
# Length of the 924th batch: 30
# Length of the 925th batch: 30
# Length of the 926th batch: 30
# Length of the 927th batch: 30
# Length of the 928th batch: 30
# Length of the 929th batch: 30
# Length of the 930th batch: 30
# Length of the 931th batch: 30
# Length of the 932th batch: 30
# Length of the 933th batch: 30
# Length of the 934th batch: 30
# Length of the 935th batch: 30
# Length of the 936th batch: 30
# Length of the 937th batch: 30
# Length of the 938th batch: 30
# Length of the 939th batch: 30
# Length of the 940th batch: 30
# Length of the 941th batch: 30
# Length of the 942th batch: 30
# Length of the 943th batch: 30
# Length of the 944th batch: 30
# Length of the 945th batch: 30
# Length of the 946th batch: 30
# Length of the 947th batch: 30
# Length of the 948th batch: 30
# Length of the 949th batch: 30
# Length of the 950th batch: 30
# Length of the 951th batch: 30
# Length of the 952th batch: 30
# Length of the 953th batch: 30
# Length of the 954th batch: 30
# Length of the 955th batch: 30
# Length of the 956th batch: 30
# Length of the 957th batch: 30
# Length of the 958th batch: 30
# Length of the 959th batch: 30
# Length of the 960th batch: 30
# Length of the 961th batch: 30
# Length of the 962th batch: 30
# Length of the 963th batch: 30
# Length of the 964th batch: 30
# Length of the 965th batch: 30
# Length of the 966th batch: 30
# Length of the 967th batch: 30
# Length of the 968th batch: 30
# Length of the 969th batch: 30
# Length of the 970th batch: 30
# Length of the 971th batch: 30
# Length of the 972th batch: 30
# Length of the 973th batch: 30
# Length of the 974th batch: 30
# Length of the 975th batch: 30
# Length of the 976th batch: 30
# Length of the 977th batch: 30
# Length of the 978th batch: 30
# Length of the 979th batch: 30
# Length of the 980th batch: 30
# Length of the 981th batch: 30
# Length of the 982th batch: 30
# Length of the 983th batch: 30
# Length of the 984th batch: 30
# Length of the 985th batch: 30
# Length of the 986th batch: 30
# Length of the 987th batch: 30
# Length of the 988th batch: 30
# Length of the 989th batch: 30
# Length of the 990th batch: 30
# Length of the 991th batch: 30
# Length of the 992th batch: 30
# Length of the 993th batch: 30
# Length of the 994th batch: 30
# Length of the 995th batch: 30
# Length of the 996th batch: 30
# Length of the 997th batch: 30
# Length of the 998th batch: 30
# Length of the 999th batch: 30
# Length of the 1000th batch: 30
# Length of the 1001th batch: 30
# Length of the 1002th batch: 30
# Length of the 1003th batch: 30
# Length of the 1004th batch: 30
# Length of the 1005th batch: 30
# Length of the 1006th batch: 30
# Length of the 1007th batch: 30
# Length of the 1008th batch: 30
# Length of the 1009th batch: 30
# Length of the 1010th batch: 30
# Length of the 1011th batch: 30
# Length of the 1012th batch: 30
# Length of the 1013th batch: 30
# Length of the 1014th batch: 30
# Length of the 1015th batch: 30
# Length of the 1016th batch: 30
# Length of the 1017th batch: 30
# Length of the 1018th batch: 30
# Length of the 1019th batch: 30
# Length of the 1020th batch: 30
# Length of the 1021th batch: 30
# Length of the 1022th batch: 30
# Length of the 1023th batch: 30
# Length of the 1024th batch: 30
# Length of the 1025th batch: 30
# Length of the 1026th batch: 30
# Length of the 1027th batch: 30
# Length of the 1028th batch: 30
# Length of the 1029th batch: 30
# Length of the 1030th batch: 30
# Length of the 1031th batch: 30
# Length of the 1032th batch: 30
# Length of the 1033th batch: 30
# Length of the 1034th batch: 30
# Length of the 1035th batch: 30
# Length of the 1036th batch: 30
# Length of the 1037th batch: 30
# Length of the 1038th batch: 30
# Length of the 1039th batch: 30
# Length of the 1040th batch: 30
# Length of the 1041th batch: 30
# Length of the 1042th batch: 30
# Length of the 1043th batch: 30
# Length of the 1044th batch: 30
# Length of the 1045th batch: 30
# Length of the 1046th batch: 30
# Length of the 1047th batch: 30
# Length of the 1048th batch: 30
# Length of the 1049th batch: 30
# Length of the 1050th batch: 30
# Length of the 1051th batch: 30
# Length of the 1052th batch: 30
# Length of the 1053th batch: 30
# Length of the 1054th batch: 30
# Length of the 1055th batch: 30
# Length of the 1056th batch: 30
# Length of the 1057th batch: 30
# Length of the 1058th batch: 30
# Length of the 1059th batch: 30
# Length of the 1060th batch: 30
# Length of the 1061th batch: 30
# Length of the 1062th batch: 30
# Length of the 1063th batch: 30
# Length of the 1064th batch: 30
# Length of the 1065th batch: 30
# Length of the 1066th batch: 30
# Length of the 1067th batch: 30
# Length of the 1068th batch: 30
# Length of the 1069th batch: 30
# Length of the 1070th batch: 30
# Length of the 1071th batch: 30
# Length of the 1072th batch: 30
# Length of the 1073th batch: 30
# Length of the 1074th batch: 30
# Length of the 1075th batch: 30
# Length of the 1076th batch: 30
# Length of the 1077th batch: 30
# Length of the 1078th batch: 30
# Length of the 1079th batch: 30
# Length of the 1080th batch: 30
# Length of the 1081th batch: 30
# Length of the 1082th batch: 30
# Length of the 1083th batch: 30
# Length of the 1084th batch: 30
# Length of the 1085th batch: 30
# Length of the 1086th batch: 30
# Length of the 1087th batch: 30
# Length of the 1088th batch: 30
# Length of the 1089th batch: 30
# Length of the 1090th batch: 30
# Length of the 1091th batch: 30
# Length of the 1092th batch: 30
# Length of the 1093th batch: 30
# Length of the 1094th batch: 30
# Length of the 1095th batch: 30
# Length of the 1096th batch: 30
# Length of the 1097th batch: 30
# Length of the 1098th batch: 30
# Length of the 1099th batch: 30
# Length of the 1100th batch: 30
# Length of the 1101th batch: 30
# Length of the 1102th batch: 30
# Length of the 1103th batch: 30
# Length of the 1104th batch: 30
# Length of the 1105th batch: 30
# Length of the 1106th batch: 30
# Length of the 1107th batch: 30
# Length of the 1108th batch: 30
# Length of the 1109th batch: 30
# Length of the 1110th batch: 30
# Length of the 1111th batch: 30
# Length of the 1112th batch: 30
# Length of the 1113th batch: 30
# Length of the 1114th batch: 30
# Length of the 1115th batch: 30
# Length of the 1116th batch: 30
# Length of the 1117th batch: 30
# Length of the 1118th batch: 30
# Length of the 1119th batch: 30
# Length of the 1120th batch: 30
# Length of the 1121th batch: 30
# Length of the 1122th batch: 30
# Length of the 1123th batch: 30
# Length of the 1124th batch: 30
# Length of the 1125th batch: 30
# Length of the 1126th batch: 30
# Length of the 1127th batch: 30
# Length of the 1128th batch: 30
# Length of the 1129th batch: 30
# Length of the 1130th batch: 30
# Length of the 1131th batch: 30
# Length of the 1132th batch: 30
# Length of the 1133th batch: 30
# Length of the 1134th batch: 30
# Length of the 1135th batch: 30
# Length of the 1136th batch: 30
# Length of the 1137th batch: 30
# Length of the 1138th batch: 30
# Length of the 1139th batch: 30
# Length of the 1140th batch: 30
# Length of the 1141th batch: 30
# Length of the 1142th batch: 30
# Length of the 1143th batch: 30
# Length of the 1144th batch: 30
# Length of the 1145th batch: 30
# Length of the 1146th batch: 30
# Length of the 1147th batch: 30
# Length of the 1148th batch: 30
# Length of the 1149th batch: 30
# Length of the 1150th batch: 30
# Length of the 1151th batch: 30
# Length of the 1152th batch: 30
# Length of the 1153th batch: 30
# Length of the 1154th batch: 30
# Length of the 1155th batch: 30
# Length of the 1156th batch: 30
# Length of the 1157th batch: 30
# Length of the 1158th batch: 30
# Length of the 1159th batch: 30
# Length of the 1160th batch: 30
# Length of the 1161th batch: 30
# Length of the 1162th batch: 30
# Length of the 1163th batch: 30
# Length of the 1164th batch: 30
# Length of the 1165th batch: 30
# Length of the 1166th batch: 30
# Length of the 1167th batch: 30
# Length of the 1168th batch: 30
# Length of the 1169th batch: 30
# Length of the 1170th batch: 30
# Length of the 1171th batch: 30
# Length of the 1172th batch: 30
# Length of the 1173th batch: 30
# Length of the 1174th batch: 30
# Length of the 1175th batch: 30
# Length of the 1176th batch: 30
# Length of the 1177th batch: 30
# Length of the 1178th batch: 30
# Length of the 1179th batch: 30
# Length of the 1180th batch: 30
# Length of the 1181th batch: 30
# Length of the 1182th batch: 30
# Length of the 1183th batch: 30
# Length of the 1184th batch: 30
# Length of the 1185th batch: 30
# Length of the 1186th batch: 30
# Length of the 1187th batch: 30
# Length of the 1188th batch: 30
# Length of the 1189th batch: 30
# Length of the 1190th batch: 30
# Length of the 1191th batch: 30
# Length of the 1192th batch: 30
# Length of the 1193th batch: 30
# Length of the 1194th batch: 30
# Length of the 1195th batch: 30
# Length of the 1196th batch: 30
# Length of the 1197th batch: 30
# Length of the 1198th batch: 30
# Length of the 1199th batch: 30
# Length of the 1200th batch: 30
# Length of the 1201th batch: 30
# Length of the 1202th batch: 30
# Length of the 1203th batch: 30
# Length of the 1204th batch: 30
# Length of the 1205th batch: 30
# Length of the 1206th batch: 30
# Length of the 1207th batch: 30
# Length of the 1208th batch: 30
# Length of the 1209th batch: 30
# Length of the 1210th batch: 30
# Length of the 1211th batch: 30
# Length of the 1212th batch: 30
# Length of the 1213th batch: 30
# Length of the 1214th batch: 30
# Length of the 1215th batch: 30
# Length of the 1216th batch: 30
# Length of the 1217th batch: 30
# Length of the 1218th batch: 30
# Length of the 1219th batch: 30
# Length of the 1220th batch: 30
# Length of the 1221th batch: 30
# Length of the 1222th batch: 30
# Length of the 1223th batch: 30
# Length of the 1224th batch: 30
# Length of the 1225th batch: 30
# Length of the 1226th batch: 30
# Length of the 1227th batch: 30
# Length of the 1228th batch: 30
# Length of the 1229th batch: 30
# Length of the 1230th batch: 30
# Length of the 1231th batch: 30
# Length of the 1232th batch: 30
# Length of the 1233th batch: 30
# Length of the 1234th batch: 30
# Length of the 1235th batch: 30
# Length of the 1236th batch: 30
# Length of the 1237th batch: 30
# Length of the 1238th batch: 30
# Length of the 1239th batch: 30
# Length of the 1240th batch: 30
# Length of the 1241th batch: 30
# Length of the 1242th batch: 30
# Length of the 1243th batch: 30
# Length of the 1244th batch: 30
# Length of the 1245th batch: 30
# Length of the 1246th batch: 30
# Length of the 1247th batch: 30
# Length of the 1248th batch: 30
# Length of the 1249th batch: 30
# Length of the 1250th batch: 30
# Length of the 1251th batch: 30
# Length of the 1252th batch: 30
# Length of the 1253th batch: 30
# Length of the 1254th batch: 30
# Length of the 1255th batch: 30
# Length of the 1256th batch: 30
# Length of the 1257th batch: 30
# Length of the 1258th batch: 30
# Length of the 1259th batch: 30
# Length of the 1260th batch: 30
# Length of the 1261th batch: 30
# Length of the 1262th batch: 30
# Length of the 1263th batch: 30
# Length of the 1264th batch: 30
# Length of the 1265th batch: 30
# Length of the 1266th batch: 30
# Length of the 1267th batch: 30
# Length of the 1268th batch: 30
# Length of the 1269th batch: 30
# Length of the 1270th batch: 30
# Length of the 1271th batch: 30
# Length of the 1272th batch: 30
# Length of the 1273th batch: 30
# Length of the 1274th batch: 30
# Length of the 1275th batch: 30
# Length of the 1276th batch: 30
# Length of the 1277th batch: 30
# Length of the 1278th batch: 30
# Length of the 1279th batch: 30
# Length of the 1280th batch: 30
# Length of the 1281th batch: 30
# Length of the 1282th batch: 30
# Length of the 1283th batch: 30
# Length of the 1284th batch: 30
# Length of the 1285th batch: 30
# Length of the 1286th batch: 30
# Length of the 1287th batch: 30
# Length of the 1288th batch: 30
# Length of the 1289th batch: 30
# Length of the 1290th batch: 30
# Length of the 1291th batch: 30
# Length of the 1292th batch: 30
# Length of the 1293th batch: 30
# Length of the 1294th batch: 30
# Length of the 1295th batch: 30
# Length of the 1296th batch: 30
# Length of the 1297th batch: 30
# Length of the 1298th batch: 30
# Length of the 1299th batch: 30
# Length of the 1300th batch: 30
# Length of the 1301th batch: 30
# Length of the 1302th batch: 30
# Length of the 1303th batch: 30
# Length of the 1304th batch: 30
# Length of the 1305th batch: 30
# Length of the 1306th batch: 30
# Length of the 1307th batch: 30
# Length of the 1308th batch: 30
# Length of the 1309th batch: 30
# Length of the 1310th batch: 30
# Length of the 1311th batch: 30
# Length of the 1312th batch: 30
# Length of the 1313th batch: 30
# Length of the 1314th batch: 30
# Length of the 1315th batch: 30
# Length of the 1316th batch: 30
# Length of the 1317th batch: 30
# Length of the 1318th batch: 30
# Length of the 1319th batch: 30
# Length of the 1320th batch: 30
# Length of the 1321th batch: 30
# Length of the 1322th batch: 30
# Length of the 1323th batch: 30
# Length of the 1324th batch: 30
# Length of the 1325th batch: 30
# Length of the 1326th batch: 30
# Length of the 1327th batch: 30
# Length of the 1328th batch: 30
# Length of the 1329th batch: 30
# Length of the 1330th batch: 30
# Length of the 1331th batch: 30
# Length of the 1332th batch: 30
# Length of the 1333th batch: 30
# Length of the 1334th batch: 30
# Length of the 1335th batch: 30
# Length of the 1336th batch: 30
# Length of the 1337th batch: 30
# Length of the 1338th batch: 30
# Length of the 1339th batch: 30
# Length of the 1340th batch: 30
# Length of the 1341th batch: 30
# Length of the 1342th batch: 30
# Length of the 1343th batch: 30
# Length of the 1344th batch: 30
# Length of the 1345th batch: 30
# Length of the 1346th batch: 30
# Length of the 1347th batch: 30
# Length of the 1348th batch: 30
# Length of the 1349th batch: 30
# Length of the 1350th batch: 30
# Length of the 1351th batch: 30
# Length of the 1352th batch: 30
# Length of the 1353th batch: 30
# Length of the 1354th batch: 30
# Length of the 1355th batch: 30
# Length of the 1356th batch: 30
# Length of the 1357th batch: 30
# Length of the 1358th batch: 30
# Length of the 1359th batch: 30
# Length of the 1360th batch: 30
# Length of the 1361th batch: 30
# Length of the 1362th batch: 30
# Length of the 1363th batch: 30
# Length of the 1364th batch: 30
# Length of the 1365th batch: 30
# Length of the 1366th batch: 30
# Length of the 1367th batch: 30
# Length of the 1368th batch: 30
# Length of the 1369th batch: 30
# Length of the 1370th batch: 30
# Length of the 1371th batch: 30
# Length of the 1372th batch: 30
# Length of the 1373th batch: 30
# Length of the 1374th batch: 30
# Length of the 1375th batch: 30
# Length of the 1376th batch: 30
# Length of the 1377th batch: 30
# Length of the 1378th batch: 30
# Length of the 1379th batch: 30
# Length of the 1380th batch: 30
# Length of the 1381th batch: 30
# Length of the 1382th batch: 30
# Length of the 1383th batch: 30
# Length of the 1384th batch: 30
# Length of the 1385th batch: 30
# Length of the 1386th batch: 30
# Length of the 1387th batch: 30
# Length of the 1388th batch: 30
# Length of the 1389th batch: 30
# Length of the 1390th batch: 30
# Length of the 1391th batch: 30
# Length of the 1392th batch: 30
# Length of the 1393th batch: 30
# Length of the 1394th batch: 30
# Length of the 1395th batch: 30
# Length of the 1396th batch: 30
# Length of the 1397th batch: 30
# Length of the 1398th batch: 30
# Length of the 1399th batch: 30
# Length of the 1400th batch: 30
# Length of the 1401th batch: 30
# Length of the 1402th batch: 30
# Length of the 1403th batch: 30
# Length of the 1404th batch: 30
# Length of the 1405th batch: 30
# Length of the 1406th batch: 30
# Length of the 1407th batch: 30
# Length of the 1408th batch: 30
# Length of the 1409th batch: 30
# Length of the 1410th batch: 30
# Length of the 1411th batch: 30
# Length of the 1412th batch: 30
# Length of the 1413th batch: 30
# Length of the 1414th batch: 30
# Length of the 1415th batch: 30
# Length of the 1416th batch: 30
# Length of the 1417th batch: 30
# Length of the 1418th batch: 30
# Length of the 1419th batch: 30
# Length of the 1420th batch: 30
# Length of the 1421th batch: 30
# Length of the 1422th batch: 30
# Length of the 1423th batch: 30
# Length of the 1424th batch: 30
# Length of the 1425th batch: 30
# Length of the 1426th batch: 30
# Length of the 1427th batch: 30
# Length of the 1428th batch: 30
# Length of the 1429th batch: 30
# Length of the 1430th batch: 30
# Length of the 1431th batch: 30
# Length of the 1432th batch: 30
# Length of the 1433th batch: 30
# Length of the 1434th batch: 30
# Length of the 1435th batch: 30
# Length of the 1436th batch: 30
# Length of the 1437th batch: 30
# Length of the 1438th batch: 30
# Length of the 1439th batch: 30
# Length of the 1440th batch: 30
# Length of the 1441th batch: 30
# Length of the 1442th batch: 30
# Length of the 1443th batch: 30
# Length of the 1444th batch: 30
# Length of the 1445th batch: 30
# Length of the 1446th batch: 30
# Length of the 1447th batch: 30
# Length of the 1448th batch: 30
# Length of the 1449th batch: 30
# Length of the 1450th batch: 30
# Length of the 1451th batch: 30
# Length of the 1452th batch: 30
# Length of the 1453th batch: 30
# Length of the 1454th batch: 30
# Length of the 1455th batch: 30
# Length of the 1456th batch: 30
# Length of the 1457th batch: 30
# Length of the 1458th batch: 30
# Length of the 1459th batch: 30
# Length of the 1460th batch: 30
# Length of the 1461th batch: 30
# Length of the 1462th batch: 30
# Length of the 1463th batch: 30
# Length of the 1464th batch: 30
# Length of the 1465th batch: 30
# Length of the 1466th batch: 30
# Length of the 1467th batch: 30
# Length of the 1468th batch: 30
# Length of the 1469th batch: 30
# Length of the 1470th batch: 30
# Length of the 1471th batch: 30
# Length of the 1472th batch: 30
# Length of the 1473th batch: 30
# Length of the 1474th batch: 30
# Length of the 1475th batch: 30
# Length of the 1476th batch: 30
# Length of the 1477th batch: 30
# Length of the 1478th batch: 30
# Length of the 1479th batch: 30
# Length of the 1480th batch: 30
# Length of the 1481th batch: 30
# Length of the 1482th batch: 30
# Length of the 1483th batch: 30
# Length of the 1484th batch: 30
# Length of the 1485th batch: 30
# Length of the 1486th batch: 30
# Length of the 1487th batch: 30
# Length of the 1488th batch: 30
# Length of the 1489th batch: 30
# Length of the 1490th batch: 30
# Length of the 1491th batch: 30
# Length of the 1492th batch: 30
# Length of the 1493th batch: 30
# Length of the 1494th batch: 30
# Length of the 1495th batch: 30
# Length of the 1496th batch: 30
# Length of the 1497th batch: 30
# Length of the 1498th batch: 30
# Length of the 1499th batch: 30
# Length of the 1500th batch: 30
# Length of the 1501th batch: 30
# Length of the 1502th batch: 30
# Length of the 1503th batch: 30
# Length of the 1504th batch: 30
# Length of the 1505th batch: 30
# Length of the 1506th batch: 30
# Length of the 1507th batch: 30
# Length of the 1508th batch: 30
# Length of the 1509th batch: 30
# Length of the 1510th batch: 30
# Length of the 1511th batch: 30
# Length of the 1512th batch: 30
# Length of the 1513th batch: 30
# Length of the 1514th batch: 30
# Length of the 1515th batch: 30
# Length of the 1516th batch: 30
# Length of the 1517th batch: 30
# Length of the 1518th batch: 30
# Length of the 1519th batch: 30
# Length of the 1520th batch: 30
# Length of the 1521th batch: 30
# Length of the 1522th batch: 30
# Length of the 1523th batch: 30
# Length of the 1524th batch: 30
# Length of the 1525th batch: 30
# Length of the 1526th batch: 30
# Length of the 1527th batch: 30
# Length of the 1528th batch: 30
# Length of the 1529th batch: 30
# Length of the 1530th batch: 30
# Length of the 1531th batch: 30
# Length of the 1532th batch: 30
# Length of the 1533th batch: 30
# Length of the 1534th batch: 30
# Length of the 1535th batch: 30
# Length of the 1536th batch: 30
# Length of the 1537th batch: 30
# Length of the 1538th batch: 30
# Length of the 1539th batch: 30
# Length of the 1540th batch: 30
# Length of the 1541th batch: 30
# Length of the 1542th batch: 30
# Length of the 1543th batch: 30
# Length of the 1544th batch: 30
# Length of the 1545th batch: 30
# Length of the 1546th batch: 30
# Length of the 1547th batch: 30
# Length of the 1548th batch: 30
# Length of the 1549th batch: 30
# Length of the 1550th batch: 30
# Length of the 1551th batch: 30
# Length of the 1552th batch: 30
# Length of the 1553th batch: 30
# Length of the 1554th batch: 30
# Length of the 1555th batch: 30
# Length of the 1556th batch: 30
# Length of the 1557th batch: 30
# Length of the 1558th batch: 30
# Length of the 1559th batch: 30
# Length of the 1560th batch: 30
# Length of the 1561th batch: 30
# Length of the 1562th batch: 30
# Length of the 1563th batch: 30
# Length of the 1564th batch: 30
# Length of the 1565th batch: 30
# Length of the 1566th batch: 30
# Length of the 1567th batch: 30
# Length of the 1568th batch: 30
# Length of the 1569th batch: 30
# Length of the 1570th batch: 30
# Length of the 1571th batch: 30
# Length of the 1572th batch: 30
# Length of the 1573th batch: 30
# Length of the 1574th batch: 30
# Length of the 1575th batch: 30
# Length of the 1576th batch: 30
# Length of the 1577th batch: 30
# Length of the 1578th batch: 30
# Length of the 1579th batch: 30
# Length of the 1580th batch: 30
# Length of the 1581th batch: 30
# Length of the 1582th batch: 30
# Length of the 1583th batch: 30
# Length of the 1584th batch: 30
# Length of the 1585th batch: 30
# Length of the 1586th batch: 30
# Length of the 1587th batch: 30
# Length of the 1588th batch: 30
# Length of the 1589th batch: 30
# Length of the 1590th batch: 30
# Length of the 1591th batch: 30
# Length of the 1592th batch: 30
# Length of the 1593th batch: 30
# Length of the 1594th batch: 30
# Length of the 1595th batch: 30
# Length of the 1596th batch: 30
# Length of the 1597th batch: 30
# Length of the 1598th batch: 30
# Length of the 1599th batch: 30
# Length of the 1600th batch: 30
# Length of the 1601th batch: 30
# Length of the 1602th batch: 30
# Length of the 1603th batch: 30
# Length of the 1604th batch: 30
# Length of the 1605th batch: 30
# Length of the 1606th batch: 30
# Length of the 1607th batch: 30
# Length of the 1608th batch: 30
# Length of the 1609th batch: 30
# Length of the 1610th batch: 30
# Length of the 1611th batch: 30
# Length of the 1612th batch: 30
# Length of the 1613th batch: 30
# Length of the 1614th batch: 30
# Length of the 1615th batch: 30
# Length of the 1616th batch: 30
# Length of the 1617th batch: 30
# Length of the 1618th batch: 30
# Length of the 1619th batch: 30
# Length of the 1620th batch: 30
# Length of the 1621th batch: 30
# Length of the 1622th batch: 30
# Length of the 1623th batch: 30
# Length of the 1624th batch: 30
# Length of the 1625th batch: 30
# Length of the 1626th batch: 30
# Length of the 1627th batch: 30
# Length of the 1628th batch: 30
# Length of the 1629th batch: 30
# Length of the 1630th batch: 30
# Length of the 1631th batch: 30
# Length of the 1632th batch: 30
# Length of the 1633th batch: 30
# Length of the 1634th batch: 30
# Length of the 1635th batch: 30
# Length of the 1636th batch: 30
# Length of the 1637th batch: 30
# Length of the 1638th batch: 30
# Length of the 1639th batch: 30
# Length of the 1640th batch: 30
# Length of the 1641th batch: 30
# Length of the 1642th batch: 30
# Length of the 1643th batch: 30
# Length of the 1644th batch: 30
# Length of the 1645th batch: 30
# Length of the 1646th batch: 30
# Length of the 1647th batch: 30
# Length of the 1648th batch: 30
# Length of the 1649th batch: 30
# Length of the 1650th batch: 30
# Length of the 1651th batch: 30
# Length of the 1652th batch: 30
# Length of the 1653th batch: 30
# Length of the 1654th batch: 30
# Length of the 1655th batch: 30
# Length of the 1656th batch: 30
# Length of the 1657th batch: 30
# Length of the 1658th batch: 30
# Length of the 1659th batch: 30
# Length of the 1660th batch: 30
# Length of the 1661th batch: 30
# Length of the 1662th batch: 30
# Length of the 1663th batch: 30
# Length of the 1664th batch: 30
# Length of the 1665th batch: 30
# Length of the 1666th batch: 30
# Length of the 1667th batch: 30
# Length of the 1668th batch: 30
# Length of the 1669th batch: 30
# Length of the 1670th batch: 30
# Length of the 1671th batch: 30
# Length of the 1672th batch: 30
# Length of the 1673th batch: 30
# Length of the 1674th batch: 30
# Length of the 1675th batch: 30
# Length of the 1676th batch: 30
# Length of the 1677th batch: 30
# Length of the 1678th batch: 30
# Length of the 1679th batch: 30
# Length of the 1680th batch: 30
# Length of the 1681th batch: 30
# Length of the 1682th batch: 30
# Length of the 1683th batch: 30
# Length of the 1684th batch: 30
# Length of the 1685th batch: 30
# Length of the 1686th batch: 30
# Length of the 1687th batch: 30
# Length of the 1688th batch: 30
# Length of the 1689th batch: 30
# Length of the 1690th batch: 30
# Length of the 1691th batch: 30
# Length of the 1692th batch: 30
# Length of the 1693th batch: 30
# Length of the 1694th batch: 30
# Length of the 1695th batch: 30
# Length of the 1696th batch: 30
# Length of the 1697th batch: 30
# Length of the 1698th batch: 30
# Length of the 1699th batch: 30
# Length of the 1700th batch: 30
# Length of the 1701th batch: 30
# Length of the 1702th batch: 30
# Length of the 1703th batch: 30
# Length of the 1704th batch: 30
# Length of the 1705th batch: 30
# Length of the 1706th batch: 30
# Length of the 1707th batch: 30
# Length of the 1708th batch: 30
# Length of the 1709th batch: 30
# Length of the 1710th batch: 30
# Length of the 1711th batch: 30
# Length of the 1712th batch: 30
# Length of the 1713th batch: 30
# Length of the 1714th batch: 30
# Length of the 1715th batch: 30
# Length of the 1716th batch: 30
# Length of the 1717th batch: 30
# Length of the 1718th batch: 30
# Length of the 1719th batch: 30
# Length of the 1720th batch: 30
# Length of the 1721th batch: 30
# Length of the 1722th batch: 30
# Length of the 1723th batch: 30
# Length of the 1724th batch: 30
# Length of the 1725th batch: 30
# Length of the 1726th batch: 30
# Length of the 1727th batch: 30
# Length of the 1728th batch: 30
# Length of the 1729th batch: 30
# Length of the 1730th batch: 30
# Length of the 1731th batch: 30
# Length of the 1732th batch: 30
# Length of the 1733th batch: 30
# Length of the 1734th batch: 30
# Length of the 1735th batch: 30
# Length of the 1736th batch: 30
# Length of the 1737th batch: 30
# Length of the 1738th batch: 30
# Length of the 1739th batch: 30
# Length of the 1740th batch: 30
# Length of the 1741th batch: 30
# Length of the 1742th batch: 30
# Length of the 1743th batch: 30
# Length of the 1744th batch: 30
# Length of the 1745th batch: 30
# Length of the 1746th batch: 30
# Length of the 1747th batch: 30
# Length of the 1748th batch: 30
# Length of the 1749th batch: 30
# Length of the 1750th batch: 30
# Length of the 1751th batch: 30
# Length of the 1752th batch: 30
# Length of the 1753th batch: 30
# Length of the 1754th batch: 30
# Length of the 1755th batch: 30
# Length of the 1756th batch: 30
# Length of the 1757th batch: 30
# Length of the 1758th batch: 30
# Length of the 1759th batch: 30
# Length of the 1760th batch: 30
# Length of the 1761th batch: 30
# Length of the 1762th batch: 30
# Length of the 1763th batch: 30
# Length of the 1764th batch: 30
# Length of the 1765th batch: 30
# Length of the 1766th batch: 30
# Length of the 1767th batch: 30
# Length of the 1768th batch: 30
# Length of the 1769th batch: 30
# Length of the 1770th batch: 30
# Length of the 1771th batch: 30
# Length of the 1772th batch: 30
# Length of the 1773th batch: 30
# Length of the 1774th batch: 30
# Length of the 1775th batch: 30
# Length of the 1776th batch: 30
# Length of the 1777th batch: 30
# Length of the 1778th batch: 30
# Length of the 1779th batch: 30
# Length of the 1780th batch: 30
# Length of the 1781th batch: 30
# Length of the 1782th batch: 30
# Length of the 1783th batch: 30
# Length of the 1784th batch: 30
# Length of the 1785th batch: 30
# Length of the 1786th batch: 30
# Length of the 1787th batch: 30
# Length of the 1788th batch: 30
# Length of the 1789th batch: 13
# Number of requests: 1790
# Number of descriptions: 53683

# %%
requests_filename = '/parallel_description_requests.jsonl'

with open(path + requests_filename, 'w') as f:
    for job in jobs:
        json_string = json.dumps(job)
        f.write(json_string + "\n")

# %%
import asyncio

output_file = '/parallel_output.jsonl'

save_path = path + output_file

if os.path.exists(save_path):
    os.remove(save_path)

requests_file_path = path + requests_filename

key = os.getenv('OPENAI_API_KEY')

if __name__ == "__main__":
    await process_api_requests_from_file(
        requests_filepath=requests_file_path,
        save_filepath=save_path,
        request_url="https://api.openai.com/v1/chat/completions",
        api_key=key,
        max_requests_per_minute=float(3_000 * 0.5),
        max_tokens_per_minute=float(250_000 * 0.5),
        token_encoding_name="cl100k_base",
        max_attempts=int(5),
        logging_level=int(logging.INFO),
    )
# Out:
# INFO:root:Starting request #0
# INFO:root:Starting request #1
# INFO:root:Starting request #2
# INFO:root:Starting request #3
# INFO:root:Starting request #4
# INFO:root:Starting request #5
# INFO:root:Starting request #6
# INFO:root:Starting request #7
# INFO:root:Starting request #8
# INFO:root:Starting request #9
# INFO:root:Starting request #10
# INFO:root:Starting request #11
# INFO:root:Starting request #12
# INFO:root:Starting request #13
# INFO:root:Starting request #14
# INFO:root:Starting request #15
# INFO:root:Starting request #16
# INFO:root:Starting request #17
# INFO:root:Parallel processing complete. Results saved to /home/donovan/code/cse447/Audio-to-Language-Alignment-via-Musical-Sentiment/Dataset/data/parallel_output.jsonl

# %%
prefixed_all_descriptions = []

with open(save_path, 'r') as read_file:

    json_list = list(read_file)
    print(f'Number of responses: {len(json_list)}')
    for json_str in json_list:
        _, response = json.loads(json_str)

        content = response['choices'][0]['message']['content']
        
        start_of_list = content.find('[')
        end_of_list = content.rfind(']')

        content = content[start_of_list:end_of_list + 1]
        content = content.replace('}', '')
        content = content.replace(':', ';')
        print(content)
    
        my_list = json.loads(content)
        prefixed_all_descriptions.extend(my_list)
        

print(f'Number of descriptions: {len(prefixed_all_descriptions)}\n')

for description in prefixed_all_descriptions[0:3]:
    print(description)

print(f'Number of descriptions: {len(prefixed_all_descriptions)}')

numbers = set(range(0, num_data_points))
for description in prefixed_all_descriptions:
    temp_str = description.split(';')[0].split('#')[1].strip()
    num = int(temp_str)
    numbers.remove(num)

for number in numbers:
    print(f'Missing number: {number}')
# Out:
# Number of responses: 18
# ["SEGMENT#00510; The lyrics are lustful and admiring.", "SEGMENT#00511; The lyrics are flirtatious and appreciative.", "SEGMENT#00512; The lyrics are sensual and craving.", "SEGMENT#00513; The lyrics are infatuated and alluring.", "SEGMENT#00514; The lyrics are captivated and inviting.", "SEGMENT#00515; The lyrics are suggestive and mesmerized.", "SEGMENT#00516; The lyrics are intrigued and impressed."]
# [
#     "SEGMENT# 00090; The lyrics are lonely and abandoned.",
#     "SEGMENT# 00091; The lyrics are lost and troubled.",
#     "SEGMENT# 00092; The lyrics are rebellious and daring.",
#     "SEGMENT# 00093; The lyrics are determined and fearless.",
#     "SEGMENT# 00094; The lyrics are isolated and independent.",
#     "SEGMENT# 00095; The lyrics are alone and self-reliant.",
#     "SEGMENT# 00096; The lyrics are castaway.",
#     "SEGMENT# 00097; The lyrics are resolute and anti-war.",
#     "SEGMENT# 00098; The lyrics are driven and purposeful.",
#     "SEGMENT# 00099; The lyrics are forsaken and isolated.",
#     "SEGMENT# 00100; The lyrics are solitary and self-sufficient.",
#     "SEGMENT# 00101; The lyrics are castaway.",
#     "SEGMENT# 00102; The lyrics are apprehensive and forgetful.",
#     "SEGMENT# 00103; The lyrics are hopeful and fleeting.",
#     "SEGMENT# 00104; The lyrics are cyclical and repetitive.",
#     "SEGMENT# 00105; The lyrics are heroic and protective.",
#     "SEGMENT# 00106; The lyrics are mystical and enchanting.",
#     "SEGMENT# 00107; The lyrics are divine and bright.",
#     "SEGMENT# 00108; The lyrics are fierce and unyielding.",
#     "SEGMENT# 00109; The lyrics are radiant and emerging.",
#     "SEGMENT# 00110; The lyrics are energetic and triumphant.",
#     "SEGMENT# 00111; The lyrics are heroic and defensive.",
#     "SEGMENT# 00112; The lyrics are resolute and adventurous.",
#     "SEGMENT# 00113; The lyrics are bright and energetic.",
#     "SEGMENT# 00114; The lyrics are worried and uncertain.",
#     "SEGMENT# 00115; The lyrics are gritty and harsh.",
#     "SEGMENT# 00116; The lyrics are hesitant and cautious.",
#     "SEGMENT# 00117; The lyrics are conflicted and resistant.",
#     "SEGMENT# 00118; The lyrics are longing for reassurance.",
#     "SEGMENT# 00119; The lyrics are questioning and affirming."
# ]
# ["SEGMENT# 00300; The lyrics are ambiguous and nonsensical",
#  "SEGMENT# 00301; The lyrics are repetitive and nonsensical",
#  "SEGMENT# 00302; The lyrics are repetitive and nonsensical",
#  "SEGMENT# 00303; The lyrics convey frustration and miscommunication",
#  "SEGMENT# 00304; The lyrics are intense and visceral",
#  "SEGMENT# 00305; The lyrics convey dependency and reliance",
#  "SEGMENT# 00306; The lyrics are sensual and romantic",
#  "SEGMENT# 00307; The lyrics suggest seduction and manipulation",
#  "SEGMENT# 00308; The lyrics are suggestive and flirtatious",
#  "SEGMENT# 00309; The lyrics are empowering and confident",
#  "SEGMENT# 00310; The lyrics are assertive and self-assured",
#  "SEGMENT# 00311; The lyrics are playful and teasing",
#  "SEGMENT# 00312; The lyrics are suggestive and provocative",
#  "SEGMENT# 00313; The lyrics are dreamy and romantic",
#  "SEGMENT# 00314; The lyrics are empowering and self-assured",
#  "SEGMENT# 00315; The lyrics praise someone's confidence and charisma",
#  "SEGMENT# 00316; The lyrics are celebratory and admiring",
#  "SEGMENT# 00317; The lyrics are admiring and enthusiastic",
#  "SEGMENT# 00318; The lyrics are sensual and intimate",
#  "SEGMENT# 00319; The lyrics express frustration and disappointment",
#  "SEGMENT# 00320; The lyrics convey feelings of inadequacy and failure",
#  "SEGMENT# 00321; The lyrics convey resignation and indifference",
#  "SEGMENT# 00322; The lyrics express determination and defiance",
#  "SEGMENT# 00323; The lyrics convey feelings of betrayal and disillusionment",
#  "SEGMENT# 00324; The lyrics express frustration and confusion",
#  "SEGMENT# 00325; The lyrics convey a plea for guidance and understanding",
#  "SEGMENT# 00326; The lyrics convey frustration and apathy",
#  "SEGMENT# 00327; The lyrics express determination and resolve",
#  "SEGMENT# 00328; The lyrics convey disappointment and resignation",
#  "SEGMENT# 00329; The lyrics convey defiance and readiness for confrontation"]
# ["SEGMENT#00240; The lyrics are questioning emotions and uncertainty",
# "SEGMENT#00241; The lyrics are expressing a lack of understanding from someone else",
# "SEGMENT#00242; The lyrics are contemplating the distinction between lies and truth",
# "SEGMENT#00243; The lyrics are unsure about what action to take",
# "SEGMENT#00244; The lyrics are feeling abandoned and betrayed",
# "SEGMENT#00245; The lyrics are feeling abandoned and exposed",
# "SEGMENT#00246; The lyrics are searching for someone within oneself",
# "SEGMENT#00247; The lyrics are unsure about what action to take",
# "SEGMENT#00248; The lyrics are feeling abandoned and betrayed",
# "SEGMENT#00249; The lyrics are feeling abandoned and exposed",
# "SEGMENT#00250; The lyrics are searching for someone within oneself",
# "SEGMENT#00251; The lyrics are unsure about what action to take",
# "SEGMENT#00252; The lyrics are expressive with vocalizations",
# "SEGMENT#00253; The lyrics are expressive with vocalizations",
# "SEGMENT#00254; The lyrics are revealing a secret desire",
# "SEGMENT#00255; The lyrics are expressing a desire for pleasure",
# "SEGMENT#00256; The lyrics are experiencing intense physical sensations",
# "SEGMENT#00257; The lyrics are embracing arousal in the darkness",
# "SEGMENT#00258; The lyrics are embracing love in the darkness",
# "SEGMENT#00259; The lyrics are longing for physical intimacy",
# "SEGMENT#00260; The lyrics are expressing overwhelming pleasure",
# "SEGMENT#00261; The lyrics are experiencing intense physical sensations",
# "SEGMENT#00262; The lyrics are embracing love in the darkness",
# "SEGMENT#00263; The lyrics are longing for physical intimacy",
# "SEGMENT#00264; The lyrics are embracing love and desire",
# "SEGMENT#00265; The lyrics are embracing love and desire",
# "SEGMENT#00266; The lyrics are urging action and passion",
# "SEGMENT#00267; The lyrics are filled with excitement and anticipation",
# "SEGMENT#00268; The lyrics are yearning for love in the darkness",
# "SEGMENT#00269; The lyrics are yearning for love and togetherness"]
# ["SEGMENT# 00480; The lyrics are reflective and slightly melancholic.",
# "SEGMENT# 00481; The lyrics convey a sense of longing and desire for more.",
# "SEGMENT# 00482; The lyrics express a sense of urgency and encouragement.",
# "SEGMENT# 00483; The lyrics encourage embracing positivity and radiance.",
# "SEGMENT# 00484; The lyrics speak to the importance of making positive changes.",
# "SEGMENT# 00485; The lyrics hint at the possibility of experiencing joy and happiness.",
# "SEGMENT# 00486; The lyrics emphasize the potential for achieving everything.",
# "SEGMENT# 00487; The lyrics urge action and promptness.",
# "SEGMENT# 00488; The lyrics emphasize the importance of shining bright.",
# "SEGMENT# 00489; The lyrics convey a message of significance and importance.",
# "SEGMENT# 00490; The lyrics highlight the significance of a particular individual.",
# "SEGMENT# 00491; The lyrics urge not to delay and to embrace positivity.",
# "SEGMENT# 00492; The lyrics suggest a desire to show affection and appreciation.",
# "SEGMENT# 00493; The lyrics emphasize the importance of a particular individual.",
# "SEGMENT# 00494; The lyrics encourage embracing positivity and radiance.",
# "SEGMENT# 00495; The lyrics convey a sense of empathy and concern for others.",
# "SEGMENT# 00496; The lyrics express determination and commitment.",
# "SEGMENT# 00497; The lyrics convey a sense of isolation and desperation.",
# "SEGMENT# 00498; The lyrics express love and support.",
# "SEGMENT# 00499; The lyrics suggest feelings of difficulty and loneliness.",
# "SEGMENT# 00500; The lyrics convey a sense of distress and emptiness.",
# "SEGMENT# 00501; The lyrics express love and compassion.",
# "SEGMENT# 00502; The lyrics convey feelings of difficulty and loneliness.",
# "SEGMENT# 00503; The lyrics describe a sense of excitement and sensuality.",
# "SEGMENT# 00504; The lyrics convey a playful and flirtatious tone.",
# "SEGMENT# 00505; The lyrics describe a feeling of intense attraction and desire.",
# "SEGMENT# 00506; The lyrics convey passion and desire.",
# "SEGMENT# 00507; The lyrics speak of a noisy and disruptive situation.",
# "SEGMENT# 00508; The lyrics express admiration for someone's physical appearance.",
# "SEGMENT# 00509; The lyrics describe a strong physical attraction and connection."]
# [
# "SEGMENT# 00060; The lyrics are filled with despair and a desire for death.",
# "SEGMENT# 00061; The lyrics express confusion about someone's thoughts and feelings.",
# "SEGMENT# 00062; The lyrics convey a longing for someone to always be present.",
# "SEGMENT# 00063; The lyrics describe a growing feeling and emotion.",
# "SEGMENT# 00064; The lyrics talk about waiting for someone who is as fleeting as sand.",
# "SEGMENT# 00065; The lyrics depict admiration for the physical attributes of a person.",
# "SEGMENT# 00066; The lyrics express a willingness to do anything for the person being addressed.",
# "SEGMENT# 00067; The lyrics suggest that something desired never returns.",
# "SEGMENT# 00068; The lyrics convey that something becomes easier with knowledge.",
# "SEGMENT# 00069; The lyrics express a desire for someone to stay endlessly.",
# "SEGMENT# 00070; The lyrics depict a strong physical attraction and desire for closeness.",
# "SEGMENT# 00071; The lyrics express longing for something that is fleeting and unattainable.",
# "SEGMENT# 00072; The lyrics convey a sense of worth and value that may not be fully recognized.",
# "SEGMENT# 00073; The lyrics reflect a distance from achieving desired goals.",
# "SEGMENT# 00074; The lyrics depict emotional distress and vulnerability.",
# "SEGMENT# 00075; The lyrics convey a struggle with self-identity and self-acceptance.",
# "SEGMENT# 00076; The lyrics describe feeling overwhelmed by one's flaws.",
# "SEGMENT# 00077; The lyrics express a desire for heavenly intervention.",
# "SEGMENT# 00078; The lyrics convey a sense of being wonderfully made.",
# "SEGMENT# 00079; The lyrics suggest a need for healing and redemption.",
# "SEGMENT# 00080; The lyrics reflect self-loathing and internal struggle.",
# "SEGMENT# 00081; The lyrics describe feeling inadequate and imperfect.",
# "SEGMENT# 00082; The lyrics convey a desire to fit in and conform.",
# "SEGMENT# 00083; The lyrics talk about facing personal demons and struggles.",
# "SEGMENT# 00084; The lyrics express a desire to escape one's own identity and shortcomings.",
# "SEGMENT# 00085; The lyrics depict feeling overwhelmed by one's imperfections.",
# "SEGMENT# 00086; The lyrics express a plea for belief and understanding.",
# "SEGMENT# 00087; The lyrics describe embarking on a journey with no return.",
# "SEGMENT# 00088; The lyrics convey a sense of reclaiming control and purpose."
# ]
# ["SEGMENT# 00150; The lyrics are empowering and self-affirming.",
# "SEGMENT# 00151; The lyrics express loneliness and a fleeting sense of happiness.",
# "SEGMENT# 00152; The lyrics depict a feeling of being disconnected and out of reach.",
# "SEGMENT# 00153; The lyrics convey a plea for company and closeness.",
# "SEGMENT# 00154; The lyrics describe a blurry reality and a unique connection.",
# "SEGMENT# 00155; The lyrics show a sense of restlessness and disillusionment.",
# "SEGMENT# 00156; The lyrics express a sense of relief and discovery.",
# "SEGMENT# 00157; The lyrics evoke a feeling of finality and nostalgia.",
# "SEGMENT# 00158; The lyrics convey a sense of being trapped but not alone.",
# "SEGMENT# 00159; The lyrics express a feeling of being stuck with no options.",
# "SEGMENT# 00160; The lyrics depict a sense of endless repetition and hopelessness.",
# "SEGMENT# 00161; The lyrics convey a sense of being lost with no destination.",
# "SEGMENT# 00162; The lyrics express a feeling of finally finding closure.",
# "SEGMENT# 00163; The lyrics evoke a sense of quiet and emptiness.",
# "SEGMENT# 00164; The lyrics convey a plea for companionship and support.",
# "SEGMENT# 00165; The lyrics describe someone vibrant and colorful.",
# "SEGMENT# 00166; The lyrics portray movement and fluidity.",
# "SEGMENT# 00167; The lyrics depict someone captivating and alluring.",
# "SEGMENT# 00168; The lyrics convey a sense of love and admiration.",
# "SEGMENT# 00169; The lyrics evoke a feeling of continuous change and beauty.",
# "SEGMENT# 00170; The lyrics portray a sense of freedom and serenity.",
# "SEGMENT# 00171; The lyrics express a sense of growth and evolution.",
# "SEGMENT# 00172; The lyrics depict comfort and affection.",
# "SEGMENT# 00173; The lyrics convey a sense of wonder and fulfillment.",
# "SEGMENT# 00174; The lyrics evoke a feeling of constant transformation and beauty.",
# "SEGMENT# 00175; The lyrics convey a sense of perpetual movement and change.",
# "SEGMENT# 00176; The lyrics portray a sense of calm and tranquility.",
# "SEGMENT# 00177; The lyrics evoke a feeling of continuity and progression.",
# "SEGMENT# 00178; The lyrics convey a sense of departure and beauty.",
# "SEGMENT# 00179; The lyrics portray a sense of peacefulness and movement."]
# ["SEGMENT#00420; The lyrics are desperate and seeking escape.",
# "SEGMENT#00421; The lyrics are about finding solace in being alone.",
# "SEGMENT#00422; The lyrics are about waiting for a call while feeling ignored.",
# "SEGMENT#00423; The lyrics are about a halted heart.",
# "SEGMENT#00424; The lyrics are about feeling lost and needing to be found.",
# "SEGMENT#00425; The lyrics are about feeling disconnected and unattractive.",
# "SEGMENT#00426; The lyrics are about wanting to avoid a heart attack.",
# "SEGMENT#00427; The lyrics are about waiting for a call for connection.",
# "SEGMENT#00428; The lyrics are about needing downtime to be fine.",
# "SEGMENT#00429; The lyrics are about uncertain paths.",
# "SEGMENT#00430; The lyrics are about standing by someone.",
# "SEGMENT#00431; The lyrics are about feeling fine despite a heart attack.",
# "SEGMENT#00432; The lyrics are about not returning from an escape.",
# "SEGMENT#00433; The lyrics are about needing to get away from a heart attack.",
# "SEGMENT#00434; The lyrics are about finding solitude.",
# "SEGMENT#00435; The lyrics are about seeing through a smile and eyes.",
# "SEGMENT#00436; The lyrics are about a crumbling love.",
# "SEGMENT#00437; The lyrics are about listening to a calling heart.",
# "SEGMENT#00438; The lyrics are about uncertainty and listening to the heart.",
# "SEGMENT#00439; The lyrics are about saying goodbye.",
# "SEGMENT#00440; The lyrics are about losing precious time.",
# "SEGMENT#00441; The lyrics are about not everything being as it seems.",
# "SEGMENT#00442; The lyrics are about following the heart.",
# "SEGMENT#00443; The lyrics are about listening to the heart before making a decision.",
# "SEGMENT#00444; The lyrics are describing unnoticed feelings and a voice in the sky.",
# "SEGMENT#00445; The lyrics are about the sound of an angel's voice in the sky.",
# "SEGMENT#00446; The lyrics are about hearing whispers of sweet moments and swirling thoughts.",
# "SEGMENT#00447; The lyrics are about feeling abandoned.",
# "SEGMENT#00448; The lyrics are about unrequited love and feeling like a burden.",
# "SEGMENT#00449; The lyrics are about unexpressed feelings." ]
# ["SEGMENT# 00000; The lyrics are romantic and appreciative", "SEGMENT# 00001; The lyrics are about finding relief from pain", "SEGMENT# 00002; The lyrics are about seeking guidance", "SEGMENT# 00003; The lyrics are about feeling lost for words", "SEGMENT# 00004; The lyrics are about a sense of truth", "SEGMENT# 00005; The lyrics are about being emotionally entangled", "SEGMENT# 00006; The lyrics are apologetic", "SEGMENT# 00007; The lyrics are about difficulty in expressing oneself", "SEGMENT# 00008; The lyrics are asking for forgiveness", "SEGMENT# 00009; The lyrics are about time passing by", "SEGMENT# 00010; The lyrics are seeking forgiveness", "SEGMENT# 00011; The lyrics are about seeking comfort", "SEGMENT# 00012; The lyrics are hopeful for a future relationship", "SEGMENT# 00013; The lyrics are apologetic", "SEGMENT# 00014; The lyrics are about difficulty in communication", "SEGMENT# 00015; The lyrics are about longing for acceptance", "SEGMENT# 00016; The lyrics are about yearning for the right moment", "SEGMENT# 00017; The lyrics are about seeking comfort", "SEGMENT# 00018; The lyrics are hopeful for a future relationship", "SEGMENT# 00019; The lyrics are hopeful for a future relationship", "SEGMENT# 00020; The lyrics are about preparing for a journey", "SEGMENT# 00021; The lyrics are about taking a significant step", "SEGMENT# 00022; The lyrics are about unknown motivations", "SEGMENT# 00023; The lyrics are about uncertainty and fate", "SEGMENT# 00024; The lyrics are about changes in emotions", "SEGMENT# 00025; The lyrics are about changes in physical intimacy", "SEGMENT# 00026; The lyrics are about unknown reasons", "SEGMENT# 00027; The lyrics are about a vacant space", "SEGMENT# 00028; The lyrics are about uncertainty and fate", "SEGMENT# 00029; The lyrics are about changes in emotions"]
# [
# "SEGMENT#00330; The lyrics are expressing a sense of hurt and betrayal in a relationship.",
# "SEGMENT#00331; The lyrics are portraying a strong desire to escape a current situation.",
# "SEGMENT#00332; The lyrics are revealing disappointment and realization about a past lover.",
# "SEGMENT#00333; The lyrics are conveying confusion and feeling of being deceived by someone.",
# "SEGMENT#00334; The lyrics are emphasizing the pain and sadness caused by unrequited love.",
# "SEGMENT#00335; The lyrics are reflecting on the lack of love in a relationship and a plea to leave.",
# "SEGMENT#00336; The lyrics are describing a heartbreak and longing for revenge.",
# "SEGMENT#00337; The lyrics are expressing shock and disbelief at a changed and unfamiliar person.",
# "SEGMENT#00338; The lyrics are lamenting the hurtful actions of a former lover.",
# "SEGMENT#00339; The lyrics are expressing realization and disappointment about a relationship not being forever.",
# "SEGMENT#00340; The lyrics are accepting responsibility for misunderstanding love.",
# "SEGMENT#00341; The lyrics are calling for immediate action to escape a painful situation.",
# "SEGMENT#00342; The lyrics are expressing pain and rejection in a relationship.",
# "SEGMENT#00343; The lyrics are reflecting on unreciprocated love and a desire to leave.",
# "SEGMENT#00344; The lyrics are highlighting the lack of care and love from a former partner.",
# "SEGMENT#00345; The lyrics are emphasizing urgency and immediacy in a situation.",
# "SEGMENT#00346; The lyrics are describing the joy and energy of music and dancing in the streets.",
# "SEGMENT#00347; The lyrics are expressing a sense of freedom and adrenaline rush from music.",
# "SEGMENT#00348; The lyrics are depicting a passionate and unstoppable energy within.",
# "SEGMENT#00349; The lyrics are reflecting on the uncertainty and excitement of a thrilling experience.",
# "SEGMENT#00350; The lyrics are repeating a catchy and upbeat chorus line.",
# "SEGMENT#00351; The lyrics are describing a heightened excitement and energy in the presence of someone.",
# "SEGMENT#00352; The lyrics are expressing losing control and feeling intense desire.",
# "SEGMENT#00353; The lyrics are showcasing a struggle between right and wrong feelings about a situation.",
# "SEGMENT#00354; The lyrics are expressing a desire for someone to stay and be close.",
# "SEGMENT#00355; The lyrics are asking if the listener is ready to dance and move their body.",
# "SEGMENT#00356; The lyrics are encouraging the listener to dance and move energetically.",
# "SEGMENT#00357; The lyrics are reflecting on feeling stronger despite uncertainty in a situation.",
# "SEGMENT#00358; The lyrics are expressing a longing for someone to stay close.",
# "SEGMENT#00359; The lyrics are expressing a deep desire for someone to stay and be present."
# ]
# [
# "SEGMENT# 00450; The lyrics are nostalgic and bittersweet.",
# "SEGMENT# 00451; The lyrics are about moving on from a past love.",
# "SEGMENT# 00452; The lyrics describe the ending of a summer romance.",
# "SEGMENT# 00453; The lyrics focus on the beginning of a love story.",
# "SEGMENT# 00454; The lyrics express a sense of loss and change.",
# "SEGMENT# 00455; The lyrics reflect on the passing of time and memories.",
# "SEGMENT# 00456; The lyrics convey the fleeting nature of vacation romances.",
# "SEGMENT# 00457; The lyrics question the possibility of rekindling love.",
# "SEGMENT# 00458; The lyrics depict the necessity of parting ways.",
# "SEGMENT# 00459; The lyrics reminisce about past kisses.",
# "SEGMENT# 00460; The lyrics capture a sense of freedom and movement.",
# "SEGMENT# 00461; The lyrics convey a sense of reassurance.",
# "SEGMENT# 00462; The lyrics speak of joy and anticipation.",
# "SEGMENT# 00463; The lyrics express hope and positivity.",
# "SEGMENT# 00464; The lyrics convey excitement for a night out.",
# "SEGMENT# 00465; The lyrics focus on making someone happy.",
# "SEGMENT# 00466; The lyrics describe a moment of contemplation.",
# "SEGMENT# 00467; The lyrics reference mundane surroundings.",
# "SEGMENT# 00468; The lyrics talk about letting loose and having fun.",
# "SEGMENT# 00469; The lyrics emphasize the importance of enjoying life.",
# "SEGMENT# 00470; The lyrics convey anticipation for a fun night.",
# "SEGMENT# 00471; The lyrics express a desire for happiness.",
# "SEGMENT# 00472; The lyrics mention unconventional entertainment choices.",
# "SEGMENT# 00473; The lyrics speak of going with the flow.",
# "SEGMENT# 00474; The lyrics convey a carefree attitude.",
# "SEGMENT# 00475; The lyrics emphasize the importance of happiness.",
# "SEGMENT# 00476; The lyrics convey a sense of acceptance.",
# "SEGMENT# 00477; The lyrics are playful and whimsical.",
# "SEGMENT# 00478; The lyrics speak of musical expression.",
# "SEGMENT# 00479; The lyrics focus on admiration and aspiration."
# ]
# ["SEGMENT#00210; The lyrics are mournful and reflective.",
# "SEGMENT#00211; The lyrics depict a somber atmosphere of grief.",
# "SEGMENT#00212; The lyrics suggest a promise made by the speaker.",
# "SEGMENT#00213; The lyrics convey a sense of hope and love.",
# "SEGMENT#00214; The lyrics describe a downward spiral into drug use.",
# "SEGMENT#00215; The lyrics highlight a lack of help for someone in need.",
# "SEGMENT#00216; The lyrics continue to mourn the death of Conny Kramer.",
# "SEGMENT#00217; The lyrics express a feeling of devastation and loss.",
# "SEGMENT#00218; The lyrics capture a plea for a loved one to come back.",
# "SEGMENT#00219; The lyrics convey a sense of numbness and despair.",
# "SEGMENT#00220; The lyrics depict a sense of loss and finality.",
# "SEGMENT#00221; The lyrics are interrupted mid-thought.",
# "SEGMENT#00222; The lyrics depict a rebellious and defiant attitude.",
# "SEGMENT#00223; The lyrics convey a sense of defiance and confidence.",
# "SEGMENT#00224; The lyrics suggest a shared experience of defiance.",
# "SEGMENT#00225; The lyrics describe a sense of being misunderstood and judged.",
# "SEGMENT#00226; The lyrics express unity and defiance.",
# "SEGMENT#00227; The lyrics depict a sense of rebellion and resistance to conformity.",
# "SEGMENT#00228; The lyrics mention the setting of Skid Row.",
# "SEGMENT#00229; The lyrics express a defiant attitude in the face of judgment.",
# "SEGMENT#00230; The lyrics convey resilience and solidarity.",
# "SEGMENT#00231; The lyrics call for wild behavior.",
# "SEGMENT#00232; The lyrics convey a sense of defiance and resilience.",
# "SEGMENT#00233; The lyrics emphasize defiance and strength.",
# "SEGMENT#00234; The lyrics express a sense of rebelliousness and independence.",
# "SEGMENT#00235; The lyrics evoke a rebellious and defiant attitude.",
# "SEGMENT#00236; The lyrics depict a sense of coming to terms with change.",
# "SEGMENT#00237; The lyrics express a feeling of uncertainty and longing.",
# "SEGMENT#00238; The lyrics convey a sense of moving forward and letting go.",
# "SEGMENT#00239; The lyrics express lingering feelings of love and loss."]
# ["SEGMENT# 00030; The lyrics are nostalgic and bittersweet.", "SEGMENT# 00031; The lyrics convey a sense of mystery and uncertainty.", "SEGMENT# 00032; The lyrics express a sense of numbness and detachment.", "SEGMENT# 00033; The lyrics depict a feeling of loss and unfamiliarity.", "SEGMENT# 00034; The lyrics describe a lack of connection and recognition.", "SEGMENT# 00035; The lyrics convey repetition and uncertainty.", "SEGMENT# 00036; The lyrics express a feeling of slow, dragging time.", "SEGMENT# 00037; The lyrics depict being alone and knowledgeable.", "SEGMENT# 00038; The lyrics express an inability to say no.", "SEGMENT# 00039; The lyrics convey frustration and futility.", "SEGMENT# 00040; The lyrics express hope for a happy ending through love.", "SEGMENT# 00041; The lyrics convey a sense of lost innocence.", "SEGMENT# 00042; The lyrics express feeling trapped and vulnerable.", "SEGMENT# 00043; The lyrics depict being ensnared in deceit and emotion.", "SEGMENT# 00044; The lyrics express frustration and longing for love.", "SEGMENT# 00045; The lyrics convey hope for resolution through love.", "SEGMENT# 00046; The lyrics depict a cycle of futility and dependency.", "SEGMENT# 00047; The lyrics express a desire for independence through love.", "SEGMENT# 00048; The lyrics convey a sense of resignation and acceptance.", "SEGMENT# 00049; The lyrics express a plea for independence and self-reliance.", "SEGMENT# 00050; The lyrics depict feeling hurt and used.", "SEGMENT# 00051; The lyrics convey a sense of danger and repetition.", "SEGMENT# 00052; The lyrics express a feeling of deceit and manipulation.", "SEGMENT# 00053; The lyrics depict a cycle of hurt and loneliness.", "SEGMENT# 00054; The lyrics convey a promise to erase pain and hurt.", "SEGMENT# 00055; The lyrics convey a sense of shared pain and isolation.", "SEGMENT# 00056; The lyrics are a vocal expression.", "SEGMENT# 00057; The lyrics express a sense of mischief and laziness.", "SEGMENT# 00058; The lyrics depict chaos and frustration.", "SEGMENT# 00059; The lyrics convey a desire for change and improvement."]
# ["SEGMENT#00120; The lyrics are questioning if someone will love them despite their flaws.",
# "SEGMENT#00121; The lyrics describe uncertainty about what can come from difficult situations.",
# "SEGMENT#00122; The lyrics express a plea to not give up on someone and to remind them of who they are.",
# "SEGMENT#00123; The lyrics question if someone can love the imperfections of another.",
# "SEGMENT#00124; The lyrics repeat the question of whether someone will love them despite their dark side.",
# "SEGMENT#00125; The lyrics ask for reassurance that someone will not run away and will stay.",
# "SEGMENT#00126; The lyrics urge someone not to run away and to promise they will stay.",
# "SEGMENT#00127; The lyrics question if someone will love them.",
# "SEGMENT#00128; The lyrics question if someone can love the imperfections of another.",
# "SEGMENT#00129; The lyrics repeat the question of whether someone will love them despite their dark side.",
# "SEGMENT#00130; The lyrics urge someone not to run away and to promise to stay.",
# "SEGMENT#00131; The lyrics contain nonverbal sounds.",
# "SEGMENT#00132; The lyrics express a cry for help for repeating past mistakes.",
# "SEGMENT#00133; The lyrics mention hurting oneself and having no one else to blame.",
# "SEGMENT#00134; The lyrics ask for someone to be a friend and to unfold their vulnerability.",
# "SEGMENT#00135; The lyrics express a desire to be comforted and supported.",
# "SEGMENT#00136; The lyrics express a need for someone to breathe life into them.",
# "SEGMENT#00137; The lyrics assert self-acceptance and uniqueness.",
# "SEGMENT#00138; The lyrics declare ownership of one's world and accomplishments.",
# "SEGMENT#00139; The lyrics express a refusal to hide oneself and dismiss the value of life.",
# "SEGMENT#00140; The lyrics assert self-acceptance and identity confidently.",
# "SEGMENT#00141; The lyrics state a lack of need for praise or pity and assert independence.",
# "SEGMENT#00142; The lyrics express a desire to appreciate beauty and see things differently.",
# "SEGMENT#00143; The lyrics assert self-acceptance and uniqueness with confidence.",
# "SEGMENT#00144; The lyrics assert self-acceptance and taking control of one's life.",
# "SEGMENT#00145; The lyrics express a realization about the finality of life and the need to embrace one's true self.",
# "SEGMENT#00146; The lyrics assert self-acceptance and taking control of one's life.",
# "SEGMENT#00147; The lyrics assert self-acceptance and taking control of one's life.",
# "SEGMENT#00148; The lyrics express a realization about the finality of life and the need to embrace one's true self.",
# "SEGMENT#00149; The lyrics assert self-acceptance and taking control of one's life."]
# [
# "SEGMENT#00360; The lyrics are intense and powerful, describing a fast and forceful invasion.",
# "SEGMENT#00361; The lyrics are confident and bold, emphasizing tanks leading the way into hostile land.",
# "SEGMENT#00362; The lyrics are swift and relentless, comparing the movement to fast lightning.",
# "SEGMENT#00363; The lyrics are proud and competitive, celebrating the Panzer elite and their fame.",
# "SEGMENT#00364; The lyrics are menacing, focusing on leaving the dead and instilling dread.",
# "SEGMENT#00365; The lyrics are chaotic, depicting the sound of blazing guns breaking morale.",
# "SEGMENT#00366; The lyrics are assertive and aggressive, with tanks leading the way into hostile land.",
# "SEGMENT#00367; The lyrics are disrupted and disarrayed, highlighting a massive assault with broken communications.",
# "SEGMENT#00368; The lyrics are triumphant and self-assured, reinforcing the Panzer elite's name and fame.",
# "SEGMENT#00369; The lyrics are eerie and ominous, suggesting always being ahead and fueled by dread.",
# "SEGMENT#00370; The lyrics are strategic, making way for Panzer corps.",
# "SEGMENT#00371; The lyrics are victorious, with tanks claiming fame and competing as the Panzer elite.",
# "SEGMENT#00372; The lyrics are haunting, emphasizing always being ahead and fed by dread as part of the Panzer elite.",
# "SEGMENT#00373; The lyrics are romantic and longing, calling out to Ave Maria for love and devotion.",
# "SEGMENT#00374; The lyrics are dreamy and tender, describing taking Ave Maria to the same sky.",
# "SEGMENT#00375; The lyrics are desperate and yearning, seeking a word to bring life and stay in the soul.",
# "SEGMENT#00376; The lyrics are intimate and seeking comfort, asking to be enveloped and protected.",
# "SEGMENT#00377; The lyrics are passionate and consuming, expressing burning love and enamorment.",
# "SEGMENT#00378; The lyrics are affectionate and devoted, referring to Ave Maria as a treasure.",
# "SEGMENT#00379; The lyrics are hopeful and longing, asking when Ave Maria will belong.",
# "SEGMENT#00380; The lyrics are lost and seeking guidance, looking for the way out.",
# "SEGMENT#00381; The lyrics are intense and passionate, asking to be ignited with fire and nothing else.",
# "SEGMENT#00382; The lyrics are fervent and obsessed, consumed by love and enamored with the other person.",
# "SEGMENT#00383; The lyrics are loving and generous, offering everything for Ave Maria.",
# "SEGMENT#00384; The lyrics are hopeful and romantic, imagining taking Ave Maria to the same sky.",
# "SEGMENT#00385; The lyrics are pleading and curious, asking when Ave Maria will be theirs.",
# "SEGMENT#00386; The lyrics are inquisitive and yearning, questioning when Ave Maria will be theirs.",
# "SEGMENT#00387; The lyrics are melodic and repetitive, singing Ave Maria with a sense of longing.",
# "SEGMENT#00388; The lyrics are pleading and eager, asking to be told when Ave Maria will be theirs.",
# "SEGMENT#00389; The lyrics are unwilling and resigned, having no choice but to listen to the other person's case."
# ]
# ["SEGMENT# 00180; The lyrics are hopeful and dynamic.",
# "SEGMENT# 00181; The lyrics reflect the passing of time and responsibilities.",
# "SEGMENT# 00182; The lyrics show a son's desire to emulate his father.",
# "SEGMENT# 00183; The lyrics convey a sense of missed opportunities and strained relationships.",
# "SEGMENT# 00184; The lyrics express anticipation of future good times.",
# "SEGMENT# 00185; The lyrics depict a father's regret for not spending time with his son.",
# "SEGMENT# 00186; The lyrics show a son's determination to be like his father.",
# "SEGMENT# 00187; The lyrics highlight distance between a father and son.",
# "SEGMENT# 00188; The lyrics describe a son's transition to adulthood.",
# "SEGMENT# 00189; The lyrics show a father's pride in his son.",
# "SEGMENT# 00190; The lyrics depict a son's request for independence.",
# "SEGMENT# 00191; The lyrics illustrate a strained relationship between father and son.",
# "SEGMENT# 00192; The lyrics show a strained relationship between father and son.",
# "SEGMENT# 00193; The lyrics express difficulty in balancing work and family.",
# "SEGMENT# 00194; The lyrics reflect a realization of similarities between father and son.",
# "SEGMENT# 00195; The lyrics convey a sense of missed opportunities and strained relationships.",
# "SEGMENT# 00196; The lyrics express a carefree and whimsical mood.",
# "SEGMENT# 00197; The lyrics suggest attraction and spontaneity.",
# "SEGMENT# 00198; The lyrics convey a desire for commitment.",
# "SEGMENT# 00199; The lyrics express disregard for convention.",
# "SEGMENT# 00200; The lyrics depict a party atmosphere.",
# "SEGMENT# 00201; The lyrics show enthusiasm for taking a leap into commitment.",
# "SEGMENT# 00202; The lyrics convey a playful and romantic mood.",
# "SEGMENT# 00203; The lyrics express a desire for spontaneity and fun.",
# "SEGMENT# 00204; The lyrics convey a longing for commitment.",
# "SEGMENT# 00205; The lyrics express a desire for spontaneity and fun.",
# "SEGMENT# 00206; The lyrics suggest attraction and spontaneity.",
# "SEGMENT# 00207; The lyrics depict a dreamy and whimsical scene.",
# "SEGMENT# 00208; The lyrics suggest a mix of excitement and disappointment.",
# "SEGMENT# 00209; The lyrics convey a sense of wonder and discovery."]
# ["SEGMENT#00270; The lyrics are filled with nervousness and admiration towards someone the speaker is unable to approach.",
# "SEGMENT#00271; The lyrics express a desire to serenade someone easily and freely through song.",
# "SEGMENT#00272; The lyrics portray the speaker's timidness in expressing their love and admiration for someone they have feelings for.",
# "SEGMENT#00273; The lyrics reflect a sense of anticipation and desire in waiting for love to blossom.",
# "SEGMENT#00274; The lyrics urge someone to come to the window or balcony to respond to a serenade.",
# "SEGMENT#00275; The lyrics express a desire to sing about love and receive a kiss from the person being serenaded.",
# "SEGMENT#00276; The lyrics of a rap serenade compliment the recipient and express appreciation for their presence.",
# "SEGMENT#00277; The lyrics praise the intelligence and movements of the person being admired.",
# "SEGMENT#00278; The lyrics compliment the recipient's physical attributes and unique sense of style.",
# "SEGMENT#00279; The lyrics call for the recipient to come to the window for a serenade in a metropolitan setting.",
# "SEGMENT#00280; The lyrics continue to urge the recipient to come to the window for a serenade in a metropolitan setting.",
# "SEGMENT#00281; The lyrics reject the rumors about the speaker and offer genuine love and honesty to the recipient.",
# "SEGMENT#00282; The lyrics emphasize the offer of love and honesty to the recipient once more.",
# "SEGMENT#00283; The lyrics repeat the call for the recipient to come to the window for love.",
# "SEGMENT#00284; The lyrics convey a raw and emotional message written on the city walls.",
# "SEGMENT#00285; The lyrics reflect on the uncertainty and destiny that intertwine through fleeting moments.",
# "SEGMENT#00286; The lyrics highlight the transformation of a relationship into a meaningful connection.",
# "SEGMENT#00287; The lyrics appreciate the recipient's unique style and resilience in an urban environment.",
# "SEGMENT#00288; The lyrics continue to call for the recipient to come to the window for love.",
# "SEGMENT#00289; The lyrics introduce a German performer recognized for their talent on television.",
# "SEGMENT#00290; The lyrics express surprise and admiration for the performer's success in America.",
# "SEGMENT#00291; The lyrics introduce a playful and catchy phrase associated with the performer.",
# "SEGMENT#00292; The lyrics repeat the playful phrase associated with the performer.",
# "SEGMENT#00293; The lyrics playfully speculate and question the uniqueness of the performer's talent.",
# "SEGMENT#00294; The lyrics express curiosity and a desire for clarity about the performer's skills and talents.",
# "SEGMENT#00295; The lyrics reflect a strong sense of curiosity and eagerness to discover something unknown.",
# "SEGMENT#00296; The lyrics repeat the playful phrase expressing curiosity.",
# "SEGMENT#00297; The lyrics humorously express confusion and anticipation regarding the performer's talent.",
# "SEGMENT#00298; The lyrics continue to humorously speculate on the performer's mysterious talent.",
# "SEGMENT#00299; The lyrics express persistent curiosity about the performer's talent and abilities."]
# ["SEGMENT# 00390; The lyrics are reflective on feeling unaccustomed to being treated well.",
# "SEGMENT# 00391; The lyrics express surprise at being won over despite initial resistance.",
# "SEGMENT# 00392; The lyrics convey falling for someone deeply despite oneself.",
# "SEGMENT# 00393; The lyrics express admiration and love for someone's entirety.",
# "SEGMENT# 00394; The lyrics attribute being consumed by love to the other person.",
# "SEGMENT# 00395; The lyrics acknowledge underestimating the depth of love received.",
# "SEGMENT# 00396; The lyrics anticipate falling head over feet for someone regardless of reservations.",
# "SEGMENT# 00397; The lyrics confess that falling for someone is the other person's doing.",
# "SEGMENT# 00398; The lyrics appreciate the selfless gestures of the other person.",
# "SEGMENT# 00399; The lyrics recount being misled and hurt in a relationship.",
# "SEGMENT# 00400; The lyrics express coming to terms with betrayal and moving on.",
# "SEGMENT# 00401; The lyrics convey a sense of betrayal and hurt inflicted by the other person.",
# "SEGMENT# 00402; The lyrics express a firm decision to move on without the other person.",
# "SEGMENT# 00403; The lyrics emphasize the resolve to never reconcile with the other person.",
# "SEGMENT# 00404; The lyrics convey indifference towards the other person's apologies and untruths.",
# "SEGMENT# 00405; The lyrics reflect on realizing the futility of writing songs about an ex-lover.",
# "SEGMENT# 00406; The lyrics express finality and moving on from a past relationship.",
# "SEGMENT# 00407; The lyrics assert confidence and not being intimidated by past hurt.",
# "SEGMENT# 00408; The lyrics reaffirm the decision to not rekindle a past relationship.",
# "SEGMENT# 00409; The lyrics reiterate a lack of concern for the other person's deceitful words.",
# "SEGMENT# 00410; The lyrics express a strong indifference towards the other person's lies.",
# "SEGMENT# 00411; The lyrics convey a sense of liberation and not caring about the other person.",
# "SEGMENT# 00412; The lyrics mock a former lover for making wrong choices and being rejected.",
# "SEGMENT# 00413; The lyrics assert independence and reject the idea of reconciling with the other person.",
# "SEGMENT# 00414; The lyrics reiterate a strong resolve to move forward without the other person.",
# "SEGMENT# 00415; The lyrics express a firm decision to never reconcile with the other person.",
# "SEGMENT# 00416; The lyrics hint at seeking solitude and introspection for answers.",
# "SEGMENT# 00417; The lyrics express uncertainty and the desire for guidance and love.",
# "SEGMENT# 00418; The lyrics question the potential survival of love in a new setting.",
# "SEGMENT# 00419; The lyrics highlight the ineffectiveness and lingering attraction in a certain space and time."]
# Number of descriptions: 516
#
# SEGMENT#00510; The lyrics are lustful and admiring.
# SEGMENT#00511; The lyrics are flirtatious and appreciative.
# SEGMENT#00512; The lyrics are sensual and craving.
# Number of descriptions: 516
# Missing number: 89

# %% [markdown]
# ### Fix missing descriptions

# %%
jobs = []
with open(path + segments_filename, 'r') as f:
    segments = json.load(f)
    missing_descriptions = [all_lines[number] for number in numbers]

    print(missing_descriptions)

    prompt = f"Here are {len(missing_descriptions)} lines of lyrics from songs: {missing_descriptions}.  Generate a 1 sentence description of the sentiment for each line. DO NOT make it conversational. Be turse. Format the output as a JSON list of the form [<response 1>, ..., <response n> ] (not a dictionary). Start each description with: \"SEGMENT#<segment num>; The lyrics are\" ."

    messages = [
                {"role": "user"},
                ]
    messages[0]['content'] = prompt
    jobs.append({"model": model_name, "messages": messages})
    

with open(path + requests_filename, 'w') as f:
    for job in jobs:
        json_string = json.dumps(job)
        f.write(json_string + "\n")

if os.path.exists(save_path):
    os.remove(save_path)

await process_api_requests_from_file(
    requests_filepath=requests_file_path,
    save_filepath=save_path,
    request_url="https://api.openai.com/v1/chat/completions",
    api_key=key,
    max_requests_per_minute=float(3_000 * 0.5),
    max_tokens_per_minute=float(250_000 * 0.5),
    token_encoding_name="cl100k_base",
    max_attempts=int(5),
    logging_level=int(logging.INFO),
)

with open(save_path, 'r') as read_file:

    json_list = list(read_file)
    print(f'Number of responses: {len(json_list)}')
    for json_str in json_list:
        _, response = json.loads(json_str)

        content = response['choices'][0]['message']['content']
        
        start_of_list = content.find('[')
        end_of_list = content.rfind(']')

        content = content[start_of_list:end_of_list + 1]
        content = content.replace('}', '')
        content = content.replace(':', ';')
        print(content)
    
        my_list = json.loads(content)
        prefixed_all_descriptions.extend(my_list)
# Out:
# INFO:root:Starting request #0
# ['SEGMENT# 00089: an expedition into desolation road ']
# INFO:root:Parallel processing complete. Results saved to /home/donovan/code/cse447/Audio-to-Language-Alignment-via-Musical-Sentiment/Dataset/data/parallel_output.jsonl
# Number of responses: 1
# ["SEGMENT#1; The lyrics are a reference to embarking on a journey through a desolate place."]

# %%
prefixed_all_descriptions = sorted(prefixed_all_descriptions, key=lambda x: x.split(';')[0].split('#')[1].strip())


example_prefix = "SEGMENT#00000; "
prefix_len = len(example_prefix)

all_descriptions = [description[prefix_len:] for description in prefixed_all_descriptions]

print(f'Number of descriptions: {len(all_descriptions)}\n')
# Out:
# Number of descriptions: 517

# %%
descriptions_output_file = '/segments_with_descriptions.json'

with open(path + segments_filename, 'r') as read_file:
    segments = json.load(read_file)

    segments = segments[0:num_data_points]

    print(len(segments))
    print(len(all_descriptions))

    for i, segment in enumerate(segments):
        segment['description'] = all_descriptions[i]

with open(path + descriptions_output_file, 'w') as write_file:
    json.dump(segments, write_file, indent=4)
# Out:
# 517
# 517
